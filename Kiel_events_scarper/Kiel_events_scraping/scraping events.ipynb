# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support import expected_conditions as EC
import time
from bs4 import BeautifulSoup

# %%
driver = webdriver.Chrome() 
url="https://www.kiel.de/de/_info/veranstaltungskalender.php#/de/kiel/default/search/Event/mode:next_months,3/sort:chronological/view:gallery"
driver.get(url)
driver.implicitly_wait(10)
# Wait for the iframe and switch to it
WebDriverWait(driver, 10).until(EC.frame_to_be_available_and_switch_to_it((By.CSS_SELECTOR, "#et4pages_iframe")))

# Wait until events are visible
WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.CSS_SELECTOR, ".item-gallery")))

# Scroll down to load more events (optional, depending on how many events you want)
# Scroll to load all events (if lazy-loaded)
last_height = driver.execute_script("return document.body.scrollHeight")
while True:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(3)  # Wait for new content to load
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:  # Exit loop if no new content is loaded
        break
    last_height = new_height

driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

time.sleep(10)
# Use BeautifulSoup to parse the page source
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
# Wait for the page to load and locate the event elements (adjust selectors as needed)
try:
    # Locate all event elements on the page
    events = driver.find_elements(By.CSS_SELECTOR, ".media-list > .media")  # Update selector as per the actual site
except Exception as e:
    print(f"Error locating event elements: {e}")
    driver.quit()
    exit()

# Initialize an empty list to store the events
events_list = []

# Iterate through each event element
for event in events:
    # Initialize an event dictionary
    event_data = {}
    
    # Extract event name
    try:
        event_name = event.find_element(By.CSS_SELECTOR, "h4.media-heading span").text
        event_data["name"] = event_name
    except Exception as e:
        print(f"Error extracting event name: {e}")
        event_data["name"] = None

    # Extract address and time
    try:
        address = event.find_element(By.CSS_SELECTOR, "i.fa-map-marker + span").text
        event_data["address"] = address
    except Exception as e:
        print(f"Error extracting address for event: {event_name}, Error: {e}")
        event_data["address"] = None

    try:
        time = event.find_element(By.CSS_SELECTOR, "i.fa-circle + span").text
        event_data["time"] = time
    except Exception as e:
        print(f"Error extracting time for event: {event_name}, Error: {e}")
        event_data["time"] = None

    # Append the event data to the events list
    events_list.append(event_data)

# Close the driver after completing
driver.quit()

# Print the stored events
for event in events_list:
    print(event)

# %%
from datetime import datetime, timedelta

# Example: Set specific dates for today
today_date = datetime.now().strftime("%Y-%m-%d")

for event in events_list:
    event["time"] = event["time"].replace("Heute", today_date)

# %%
from datetime import datetime, timedelta
import locale

# Set locale for handling German day and month names
locale.setlocale(locale.LC_TIME, 'de_DE.UTF-8')
# Out:
# 'de_DE.UTF-8'

# %%
def parse_event_time(raw_text):
    now = datetime.now()
    today_str = now.strftime("%Y-%m-%d")
    tomorrow_str = (now + timedelta(days=1)).strftime("%Y-%m-%d")

    if "Morgen" in raw_text:  # Handle "Morgen"
        # Extract time range
        time_range = raw_text.replace("Morgen", "").strip()
        start_time, end_time = time_range.split(" - ")
        
        # Tomorrow's date
        start_datetime = datetime.strptime(f"{tomorrow_str} {start_time}", "%Y-%m-%d %H:%M")
        end_datetime = datetime.strptime(f"{tomorrow_str} {end_time}", "%Y-%m-%d %H:%M")
    
    elif "Heute" in raw_text:  # Handle "Heute"
        # Extract time range
        time_range = raw_text.split(" ")[1].strip()  # Get the part after "Heute"
        start_time, end_time = time_range.split(" - ")
        
        # Today's date
        start_datetime = datetime.strptime(f"{today_str} {start_time}", "%Y-%m-%d %H:%M")
        end_datetime = datetime.strptime(f"{today_str} {end_time}", "%Y-%m-%d %H:%M")
    
    else:  # Handle explicit dates like "Mi., 20. Nov. 13:00 - 20:00"
        # Extract date and time range
        parts = raw_text.split(", ")
        day_date = parts[1].strip()
        time_range = parts[2].strip().split(" ")[0]
        start_time, end_time = time_range.split(" - ")
        
        # Parse date
        event_date = datetime.strptime(day_date, "%d. %b.")
        event_date = event_date.replace(year=now.year)
        
        # Combine with times
        start_datetime = datetime.strptime(f"{event_date.strftime('%Y-%m-%d')} {start_time}", "%Y-%m-%d %H:%M")
        end_datetime = datetime.strptime(f"{event_date.strftime('%Y-%m-%d')} {end_time}", "%Y-%m-%d %H:%M")
    
    return start_datetime, end_datetime

# %%
for event in events_list:
    print(event)

# %%
import requests

def get_coordinates(address):
    url = "https://nominatim.openstreetmap.org/search"
    params = {"q": address, "format": "json"}
    response = requests.get(url, params=params)
    if response.status_code == 200 and response.json():
        location = response.json()[0]
        return float(location["lat"]), float(location["lon"])
    return None, None

for event in events_list:
    lat, lon = get_coordinates(event["address"])
    event["latitude"] = lat
    event["longitude"] = lon

# %%
for event in events_list:
    print(event)
# Out:
# {'name': 'Weihnachtsmarkt im CITTI-Park', 'address': 'CITTI-PARK, Mühlendamm 1, Kiel', 'time': '2024-11-18 09:00 - 20:00\nEndet in einer Stunde', 'latitude': None, 'longitude': None}
# {'name': 'Riesenrad am Bahnhof "La Noria"', 'address': 'Kiel Hauptbahnhof , Sophienblatt 25-27, Kiel', 'time': '2024-11-18 11:00 - 21:00\nEndet in 2 Stunden', 'latitude': None, 'longitude': None}
# {'name': 'Stadtwerke Eisfestival', 'address': 'Germaniahafen, Am Germaniahafen, Kiel', 'time': '2024-11-18 13:00 - 20:00\nEndet in einer Stunde', 'latitude': None, 'longitude': None}
# {'name': 'Schnippelparty', 'address': 'Nachhaltigkeitszentrum Kiel, Europaplatz 2, Kiel', 'time': '2024-11-18 17:00 - 19:00\nEndet in 21 Minuten', 'latitude': None, 'longitude': None}
# {'name': 'Das skandinavische Mittelalter und seine Medien', 'address': 'Christian-Albrechts-Universität zu Kiel | OS75, Olshausenstraße 75, Kiel', 'time': '2024-11-18 18:00 - 20:00\nEndet in einer Stunde', 'latitude': None, 'longitude': None}
# {'name': 'Alter, Gesundheit und aktiver Lebensstil', 'address': 'Institut für Sportwissenschaft, Olshausenstraße 74, Kiel', 'time': '2024-11-18 18:15 - 19:30\nEndet in einer Stunde', 'latitude': None, 'longitude': None}
# {'name': 'Dialog und Perspektiven: Die Zukunft der somalisch-deutschen Beziehung – der somalische Botschafter zu Gast in Kiel – Somali Kulturwochen (Abgesagt)', 'address': 'Anscharcampus, Weimarer Str. 6, Kiel', 'time': '2024-11-18 19:00 - 21:00\nBeginnt in 21 Minuten', 'latitude': None, 'longitude': None}
# {'name': 'Pub Quiz', 'address': 'Pogue Mahone Irish Pub Kiel, Bergstr. 15, Kiel', 'time': '2024-11-18 20:00 - 23:00\nBeginnt in einer Stunde', 'latitude': None, 'longitude': None}
# {'name': 'Jazz-Café+ im STATT-CAFÉ', 'address': 'KulturForum in der Stadtgalerie , Andreas-Gayk-Straße 31, Kiel (Innenstadt)', 'time': '2024-11-18 20:00 - 22:00\nBeginnt in einer Stunde', 'latitude': None, 'longitude': None}
# {'name': 'Der Mensch dahinter', 'address': 'Rathaus Kiel, Fleethörn 9, Kiel', 'time': 'Morgen 08:00 - 18:00\nin 13 Stunden', 'latitude': None, 'longitude': None}
# {'name': 'Weihnachtsmarkt im CITTI-Park', 'address': 'CITTI-PARK, Mühlendamm 1, Kiel', 'time': 'Morgen 09:00 - 20:00\nin 14 Stunden', 'latitude': None, 'longitude': None}
# {'name': 'Kaufrausch. Konsum und Warenwelten der 1980er Jahre', 'address': 'Stadtmuseum Warleberger Hof, Dänische Straße 19, 24103 Kiel, Kiel (Innenstadt)', 'time': 'Morgen 10:00 - 18:00\nin 15 Stunden', 'latitude': None, 'longitude': None}
# {'name': 'Prima Kunst: Johanna Blank – The Cabin', 'address': 'Stadtgalerie Kiel, Andreas-Gayk-Straße 31, Kiel', 'time': 'Morgen 10:00 - 17:00\nin 15 Stunden', 'latitude': None, 'longitude': None}
# {'name': 'Kiel festhalten. Stadtansichten von Gretel Riemann', 'address': 'Stadtmuseum Warleberger Hof, Dänische Straße 19, 24103 Kiel, Kiel (Innenstadt)', 'time': 'Morgen 10:00 - 18:00\nin 15 Stunden', 'latitude': None, 'longitude': None}
# {'name': 'Der Gewölbekeller. Kostbarkeiten aus dem Alten Kiel', 'address': 'Stadtmuseum Warleberger Hof, Dänische Straße 19, 24103 Kiel, Kiel (Innenstadt)', 'time': 'Morgen 10:00 - 18:00\nin 15 Stunden', 'latitude': None, 'longitude': None}
# {'name': 'Kiel (re)connecting.earth. Beyond Water', 'address': 'Stadtgalerie Kiel, Andreas-Gayk-Straße 31, Kiel', 'time': 'Morgen 10:00 - 17:00\nin 15 Stunden', 'latitude': None, 'longitude': None}
# {'name': 'Riesenrad am Bahnhof "La Noria"', 'address': 'Kiel Hauptbahnhof , Sophienblatt 25-27, Kiel', 'time': 'Morgen 11:00 - 21:00\nin 16 Stunden', 'latitude': None, 'longitude': None}
# {'name': '"Raum für neue Schaukelkultur"', 'address': 'Pop-up Pavillon, Alter Markt 17, Kiel', 'time': 'Morgen 11:00 - 18:00\nin 16 Stunden', 'latitude': None, 'longitude': None}
# {'name': 'Kunstraum Sconeberg mit ganzjährigem Ausstellungsangebot', 'address': 'Kunstraum Sconeberg, Bahnhofstr. 18, Schönberg (Holstein)', 'time': 'Morgen 11:00 - 18:00\nin 16 Stunden', 'latitude': None, 'longitude': None}
# {'name': 'Stadtwerke Eisfestival', 'address': 'Germaniahafen, Am Germaniahafen, Kiel', 'time': 'Morgen 13:00 - 20:00\nin 18 Stunden', 'latitude': None, 'longitude': None}
# {'name': 'WärmeZeit', 'address': 'Hof Akkerboom e.V., Stockholmstr. 159, Kiel', 'time': 'Morgen 15:00 - 17:00\nin 20 Stunden', 'latitude': None, 'longitude': None}
# {'name': 'Bilderbuchkino: Malwine in der Badewanne', 'address': 'Zentralbücherei im Neuen Rathaus, Andreas-Gayk-Straße 31, Kiel', 'time': 'Morgen 15:30 - 16:30\nin 21 Stunden', 'latitude': None, 'longitude': None}
# {'name': 'Kuratorische Führung: Beyond Water.', 'address': 'Stadtgalerie Kiel, Andreas-Gayk-Straße 31, Kiel', 'time': 'Morgen 18:00 - 19:30\nin einem Tag', 'latitude': None, 'longitude': None}
# {'name': 'Ukraine', 'address': 'Audimax der CAU, Christian-Albrechts-Platz 2, Kiel', 'time': 'Morgen 18:00 - 19:30\nin einem Tag', 'latitude': None, 'longitude': None}
# {'name': 'LeseLounge mit Miriam Böttger & Maria Bidian', 'address': 'Literaturhaus Schleswig-Holstein, Schwanenweg 13, Kiel', 'time': 'Morgen 19:00 - 21:00\nin einem Tag', 'latitude': None, 'longitude': None}
# {'name': 'Somali Quiz – Somali Kulturwochen', 'address': 'Kommunikationszentrum Hansastrasse 48 e. V., Hansastraße 48, Kiel', 'time': 'Morgen 19:00 - 22:00\nin einem Tag', 'latitude': None, 'longitude': None}
# {'name': 'Karaoke', 'address': 'Pogue Mahone Irish Pub Kiel, Bergstr. 15, Kiel', 'time': 'Morgen 22:00 - Mi., 20. Nov. 02:00\nin einem Tag', 'latitude': None, 'longitude': None}
# {'name': 'Der Mensch dahinter', 'address': 'Rathaus Kiel, Fleethörn 9, Kiel', 'time': 'Mi., 20. Nov. 08:00 - 18:00\nin 2 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Weihnachtsmarkt im CITTI-Park', 'address': 'CITTI-PARK, Mühlendamm 1, Kiel', 'time': 'Mi., 20. Nov. 09:00 - 20:00\nin 2 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Prima Kunst: Johanna Blank – The Cabin', 'address': 'Stadtgalerie Kiel, Andreas-Gayk-Straße 31, Kiel', 'time': 'Mi., 20. Nov. 10:00 - 17:00\nin 2 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Kiel festhalten. Stadtansichten von Gretel Riemann', 'address': 'Stadtmuseum Warleberger Hof, Dänische Straße 19, 24103 Kiel, Kiel (Innenstadt)', 'time': 'Mi., 20. Nov. 10:00 - 18:00\nin 2 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Kaufrausch. Konsum und Warenwelten der 1980er Jahre', 'address': 'Stadtmuseum Warleberger Hof, Dänische Straße 19, 24103 Kiel, Kiel (Innenstadt)', 'time': 'Mi., 20. Nov. 10:00 - 18:00\nin 2 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Der Gewölbekeller. Kostbarkeiten aus dem Alten Kiel', 'address': 'Stadtmuseum Warleberger Hof, Dänische Straße 19, 24103 Kiel, Kiel (Innenstadt)', 'time': 'Mi., 20. Nov. 10:00 - 18:00\nin 2 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Kiel (re)connecting.earth. Beyond Water', 'address': 'Stadtgalerie Kiel, Andreas-Gayk-Straße 31, Kiel', 'time': 'Mi., 20. Nov. 10:00 - 17:00\nin 2 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Riesenrad am Bahnhof "La Noria"', 'address': 'Kiel Hauptbahnhof , Sophienblatt 25-27, Kiel', 'time': 'Mi., 20. Nov. 11:00 - 21:00\nin 2 Tagen', 'latitude': None, 'longitude': None}
# {'name': '"Raum für neue Schaukelkultur"', 'address': 'Pop-up Pavillon, Alter Markt 17, Kiel', 'time': 'Mi., 20. Nov. 11:00 - 18:00\nin 2 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Kunstraum Sconeberg mit ganzjährigem Ausstellungsangebot', 'address': 'Kunstraum Sconeberg, Bahnhofstr. 18, Schönberg (Holstein)', 'time': 'Mi., 20. Nov. 11:00 - 18:00\nin 2 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Stadtwerke Eisfestival', 'address': 'Germaniahafen, Am Germaniahafen, Kiel', 'time': 'Mi., 20. Nov. 13:00 - 20:00\nin 2 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Mittagskonzert - 30 Minuten Musik im Bach-Saal', 'address': 'Bachsaal am Musikwissenschaftlichen Institut der CAU, Rudolf-Höber-Straße 3, Kiel', 'time': 'Mi., 20. Nov. 13:00 - 13:30\nin 2 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Open Workshop im Makerspace', 'address': 'Stadtteilbücherei Friedrichsort, Zum Dänischen Wohld 23, Kiel', 'time': 'Mi., 20. Nov. 14:00 - 18:00\nin 2 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Kulturcafé', 'address': 'Kulturinitiative Elmschenhagen, Karlsbader Str. 86 · 24146 Kiel, Kiel', 'time': 'Mi., 20. Nov. 15:00 - 17:00\nin 2 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Ausstellung „1918 – 1989 – Heute?“', 'address': 'Kulturstation Toweddern, Hultschiner Str. 43, Kiel (Kiel-Elmschenhagen)', 'time': 'Mi., 20. Nov. 15:00 - 17:00\nin 2 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Der Sprung ins All – das Abenteuer der Raumfahrt', 'address': 'Mediendom, Sokratesplatz 6, Kiel', 'time': 'Mi., 20. Nov. 17:00 - 18:00\nin 2 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Lesung - Lena Johannson', 'address': 'Maritimes Viertel - Kultur am Kanal e.V., Arkonastraße 1, Kiel', 'time': 'Mi., 20. Nov. 18:00 - 19:30\nin 2 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'EisDISCO powered by Casino Kiel', 'address': 'Germaniahafen, Am Germaniahafen, Kiel', 'time': 'Mi., 20. Nov. 18:00 - 21:00\nin 2 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Queen Heaven – The Original', 'address': 'Mediendom, Sokratesplatz 6, Kiel', 'time': 'Mi., 20. Nov. 18:30 - 19:45\nin 2 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Menschenrechte in Somalia: Aktuelle Herausforderungen und internationale Perspektive – Abschira Kontny: Vortrag und Diskussion – Somali Kulturwochen', 'address': 'Anscharcampus, Weimarer Str. 6, Kiel', 'time': 'Mi., 20. Nov. 19:00 - 20:30\nin 2 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Die Rosa-Luxemburg Stiftung SH präsentiert: Buchvorstellung von und mit Sabine Nuss: „Wessen Freiheit, welche Gleichheit? Das Versprechen einer anderen Vergesellschaftung“', 'address': 'Kommunikationszentrum Hansastrasse 48 e. V., Hansastraße 48, Kiel', 'time': 'Mi., 20. Nov. 20:00 - 22:00\nin 2 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Pogue Mahone Jam Session', 'address': 'Pogue Mahone Irish Pub, Bergstrasse 15, Kiel', 'time': 'Mi., 20. Nov. 20:30\nin 2 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Sneak-Preview - Die Überraschungsvorpremiere', 'address': 'Studio Filmtheater , Wilhelminenstraße 10, Kiel', 'time': 'Mi., 20. Nov. 21:00\nin 2 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Der Mensch dahinter', 'address': 'Rathaus Kiel, Fleethörn 9, Kiel', 'time': 'Do., 21. Nov. 08:00 - 18:00\nin 3 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Weihnachtsmarkt im CITTI-Park', 'address': 'CITTI-PARK, Mühlendamm 1, Kiel', 'time': 'Do., 21. Nov. 09:00 - 20:00\nin 3 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Der Gewölbekeller. Kostbarkeiten aus dem Alten Kiel', 'address': 'Stadtmuseum Warleberger Hof, Dänische Straße 19, 24103 Kiel, Kiel (Innenstadt)', 'time': 'Do., 21. Nov. 10:00 - 18:00\nin 3 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Kaufrausch. Konsum und Warenwelten der 1980er Jahre', 'address': 'Stadtmuseum Warleberger Hof, Dänische Straße 19, 24103 Kiel, Kiel (Innenstadt)', 'time': 'Do., 21. Nov. 10:00 - 18:00\nin 3 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Kiel festhalten. Stadtansichten von Gretel Riemann', 'address': 'Stadtmuseum Warleberger Hof, Dänische Straße 19, 24103 Kiel, Kiel (Innenstadt)', 'time': 'Do.,
 'address': 'Germaniahafen, Am Germaniahafen, Kiel', 'time': 'Mi., 4. Dez. 18:00 - 21:00\nin 16 Tagen', 'latitude': 54.31446325, 'longitude': 10.137061238278127}
# {'name': 'The Dark Side of the Moon Planetarium Experience', 'address': 'Mediendom, Sokratesplatz 6, Kiel', 'time': 'Mi., 4. Dez. 18:30 - 19:30\nin 16 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Ein Sommernachtstraum', 'address': 'Opernhaus, Rathausplatz 4, Kiel', 'time': 'Mi., 4. Dez. 19:00 - 21:00\nin 16 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Pure Fruit Comic-Battle zum Meer(esschutz)', 'address': 'Kommunikationszentrum Hansastrasse 48 e. V., Hansastraße 48, Kiel', 'time': 'Mi., 4. Dez. 19:30 - 21:30\nin 16 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Weihnachten mit den drei Herren', 'address': 'KulturForum in der Stadtgalerie , Andreas-Gayk-Straße 31, Kiel (Innenstadt)', 'time': 'Mi., 4. Dez. 20:00 - 22:00\nin 16 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'BAP', 'address': 'Wunderino Arena , Europaplatz 1 , Kiel', 'time': 'Mi., 4. Dez. 20:00 - 23:00\nin 16 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Pogue Mahone Jam Session', 'address': 'Pogue Mahone Irish Pub, Bergstrasse 15, Kiel', 'time': 'Mi., 4. Dez. 20:30\nin 16 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Sneak-Preview - Die Überraschungsvorpremiere', 'address': 'Studio Filmtheater , Wilhelminenstraße 10, Kiel', 'time': 'Mi., 4. Dez. 21:00\nin 16 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Der Mensch dahinter', 'address': 'Rathaus Kiel, Fleethörn 9, Kiel', 'time': 'Do., 5. Dez. 08:00 - 18:00\nin 17 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Weihnachtsmarkt im CITTI-Park', 'address': 'CITTI-PARK, Mühlendamm 1, Kiel', 'time': 'Do., 5. Dez. 09:00 - 20:00\nin 17 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Weihnachten im Sophienhof', 'address': 'Sophienhof , Sophienblatt 20, Kiel', 'time': 'Do., 5. Dez. 10:00 - 20:00\nin 17 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Kaufrausch. Konsum und Warenwelten der 1980er Jahre', 'address': 'Stadtmuseum Warleberger Hof, Dänische Straße 19, 24103 Kiel, Kiel (Innenstadt)', 'time': 'Do., 5. Dez. 10:00 - 18:00\nin 17 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Der Gewölbekeller. Kostbarkeiten aus dem Alten Kiel', 'address': 'Stadtmuseum Warleberger Hof, Dänische Straße 19, 24103 Kiel, Kiel (Innenstadt)', 'time': 'Do., 5. Dez. 10:00 - 18:00\nin 17 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Marine, Werften, Segelsport – die Geschichte der Hafenstadt Kiel', 'address': 'Schifffahrtsmuseum , Wall 65, Kiel', 'time': 'Do., 5. Dez. 10:00 - 18:00\nin 17 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Kiel festhalten. Stadtansichten von Gretel Riemann', 'address': 'Stadtmuseum Warleberger Hof, Dänische Straße 19, 24103 Kiel, Kiel (Innenstadt)', 'time': 'Do., 5. Dez. 10:00 - 18:00\nin 17 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Riesenrad am Bahnhof "La Noria"', 'address': 'Kiel Hauptbahnhof , Sophienblatt 25-27, Kiel', 'time': 'Do., 5. Dez. 11:00 - 21:00\nin 17 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Weihnachtsmarkt - Holstenplatz', 'address': 'Holstenplatz, Holstenplatz, Kiel (Vorstadt)', 'time': 'Do., 5. Dez. 11:00 - 21:00\nin 17 Tagen', 'latitude': 54.3189331, 'longitude': 10.1332736}
# {'name': 'Weihnachtsmarkt - Asmus-Bremer-Platz', 'address': 'Asmus-Bremer-Platz, Kiel', 'time': 'Do., 5. Dez. 11:00 - 21:00\nin 17 Tagen', 'latitude': 54.32139389415386, 'longitude': 10.134919099532215}
# {'name': 'Kunstraum Sconeberg mit ganzjährigem Ausstellungsangebot', 'address': 'Kunstraum Sconeberg, Bahnhofstr. 18, Schönberg (Holstein)', 'time': 'Do., 5. Dez. 11:00 - 18:00\nin 17 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Weihnachtsmarkt Rathausplatz', 'address': 'Rathausplatz, Rathausplatz, Kiel', 'time': 'Do., 5. Dez. 11:00 - 21:00\nin 17 Tagen', 'latitude': 54.3223768, 'longitude': 10.1338639}
# {'name': 'Wintermarkt Bootshafen', 'address': 'Bootshafen, Bootshafen, Kiel (Altstadt)', 'time': 'Do., 5. Dez. 12:00 - 21:00\nin 17 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Weihnachtsmarkt Bernhard-Minetti-Platz / Holtenauer Straße', 'address': 'Bernhard-Minetti-Platz, Holtenauer Straße 113, Kiel', 'time': 'Do., 5. Dez. 13:00 - 21:00\nin 17 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Stadtwerke Eisfestival', 'address': 'Germaniahafen, Am Germaniahafen, Kiel', 'time': 'Do., 5. Dez. 13:00 - 20:00\nin 17 Tagen', 'latitude': 54.31446325, 'longitude': 10.137061238278127}
# {'name': 'Basteln: Wir basteln einen Engel', 'address': 'Stadtteilbücherei Dietrichsdorf, Langer Rehm 29, Kiel', 'time': 'Do., 5. Dez. 14:30 - 17:00\nin 17 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Ausstellung „1918 – 1989 – Heute?“', 'address': 'Kulturstation Toweddern, Hultschiner Str. 43, Kiel (Kiel-Elmschenhagen)', 'time': 'Do., 5. Dez. 15:00 - 17:00\nin 17 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Vorlesestunde: Vorlesen für Kinder', 'address': 'Stadtteilbücherei Mettenhof, Sibeliusweg 2a, Kiel', 'time': 'Do., 5. Dez. 15:30 - 16:30\nin 17 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Rathausturmfahrten', 'address': 'Rathaus Kiel, Fleethörn 9, Kiel', 'time': 'Do., 5. Dez. 17:00 - 19:00\nin 17 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Hansen und die Sache mit dem Pinguin', 'address': 'Niederdeutsche Bühne, Wilhelmplatz 2, Kiel', 'time': 'Do., 5. Dez. 17:00 - 18:00\nin 17 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Rathausturmfahrten', 'address': 'Rathaus Kiel, Fleethörn 9, Kiel', 'time': 'Do., 5. Dez. 17:45 - 18:15\nin 17 Tagen', 'latitude': None, 'longitude': None}
# {'name': 'Die Welt der Anderen? Stereotype und Fremdbilder in Ost und West', 'address': 'Audimax der CAU, Christian-Albrechts-Platz 2, Kiel', 'time': 'Do., 5. Dez. 18:15 - 19:45\nin 17 Tagen', 'latitude': None, 'longitude': None}

# %%
def parse_event_time(raw_text):
    now = datetime.now()
    today_str = now.strftime("%Y-%m-%d")
    tomorrow_str = (now + timedelta(days=1)).strftime("%Y-%m-%d")

    if "Morgen" in raw_text:  # Handle "Morgen"
        # Extract time range
        time_range = raw_text.replace("Morgen", "").strip()
        start_time, end_time = time_range.split(" - ")
        
        # Tomorrow's date
        start_datetime = datetime.strptime(f"{tomorrow_str} {start_time}", "%Y-%m-%d %H:%M")
        end_datetime = datetime.strptime(f"{tomorrow_str} {end_time}", "%Y-%m-%d %H:%M")
    
    elif "Heute" in raw_text:  # Handle "Heute"
        # Extract time range
        time_range = raw_text.split(" ")[1].strip()  # Get the part after "Heute"
        start_time, end_time = time_range.split(" - ")
        
        # Today's date
        start_datetime = datetime.strptime(f"{today_str} {start_time}", "%Y-%m-%d %H:%M")
        end_datetime = datetime.strptime(f"{today_str} {end_time}", "%Y-%m-%d %H:%M")
    
    else:  # Handle explicit dates like "Mi., 20. Nov. 13:00 - 20:00"
        # Extract date and time range
        parts = raw_text.split(", ")
        day_date = parts[1].strip()
        time_range = parts[2].strip().split(" ")[0]
        start_time, end_time = time_range.split(" - ")
        
        # Parse date
        event_date = datetime.strptime(day_date, "%d. %b.")
        event_date = event_date.replace(year=now.year)
        
        # Combine with times
        start_datetime = datetime.strptime(f"{event_date.strftime('%Y-%m-%d')} {start_time}", "%Y-%m-%d %H:%M")
        end_datetime = datetime.strptime(f"{event_date.strftime('%Y-%m-%d')} {end_time}", "%Y-%m-%d %H:%M")
    
    return start_datetime, end_datetime
