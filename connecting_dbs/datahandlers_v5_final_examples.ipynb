# %%
from abc import ABC, abstractmethod
from typing import Any
from pymongo import MongoClient
from geopy.distance import geodesic
import folium
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import shape, Point
from shapely import from_wkt
import json
from thefuzz import fuzz
from datetime import timedelta
from bson import ObjectId
from langchain_chroma import Chroma
from langchain_huggingface import HuggingFaceEmbeddings

from tqdm import tqdm, trange
import warnings
from tqdm.autonotebook import tqdm, trange
# Out:
# C:\Users\dorar\AppData\Local\Temp\ipykernel_15512\203836383.py:20: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %%
warnings.filterwarnings("ignore")

# %% [markdown]
# # 1 data base handlers

# %% [markdown]
# ## parent class

# %%
class DBHandlers(ABC):

    @abstractmethod 
    def connect_db(self,Client,client_str,db_str,coll_str): 
        client = Client(client_str) #connect to mongodb client
        db = client[db_str] #connect to database
        existing_collections = db.list_collection_names() #check that dbs collections
        if coll_str not in existing_collections:
            db.create_collection(coll_str) #create collection if needed
        self.collection = db[coll_str] #connect to collection

    @abstractmethod
    def design_query_dict(self):
        query_terms = [{},{}] # {"$or":[{},{}]} returns everything
        return query_terms


    @abstractmethod
    def retrieve_data(self):
        self.data = [elem for elem in self.collection.find(self.query_dict)]

    @abstractmethod
    def check_click_radius(self,click_point,radius,data):
        in_radius = []
        for e in data:
            try:
                #try like this because of naming irregularities with yp and osm data
                try:
                    lat, lon = e["lat"],e["lon"]
                except KeyError:
                    lat, lon = e["latitude"],e["longitude"]
                other_point = (lat,lon)
                dist = geodesic(click_point, other_point).km
                if dist < radius:
                    in_radius.append(e)
            except:
                pass
        self.results = in_radius

    @abstractmethod
    def click_polygon(self,click_point, data):
        #get adminlevel=6 boundaries data
        df = pd.read_csv("sh_boundaries_6.csv")
        df = df[["name","geometry"]]
        df["geometry"] = df["geometry"].apply(from_wkt)
        gdf = gpd.GeoDataFrame(df, geometry='geometry')
        gdf.set_crs("EPSG:4326",inplace=True)

        #reorder for check
        click_point = [click_point]
        reordered_point = [(lon, lat) for lat, lon in click_point]
        reordered_point = Point(reordered_point)

        #check for intersection
        poly = df[df["geometry"].apply(lambda x: x.contains(reordered_point))]
        
        self.results = []
        for e in data:
            if "lon" in e and "lat" in e and e["lon"] is not None and e["lat"] is not None:
                reordered_coords = Point(e["lon"],e["lat"])
                if any(poly["geometry"].apply(lambda x: x.contains(reordered_coords))):
                    self.results.append(e)
        return poly


    @abstractmethod
    def no_duplicates(self,dict_list,new_dicts,key):
        for e in new_dicts:
            #if the item to add doesnt have the relevant key, put it into results list
            if key not in e:
                dict_list.append(e)
                continue
            #if its false that the new item has the same value as an already collected dict, add new item 
            if not any(e.get(key) == d.get(key) for d in dict_list):
                dict_list.append(e)
        return dict_list
    
    @abstractmethod
    def retrieve_by_id(self,Client,client_str,db_str,coll_str,batch_ids):
        self.connect_db(Client,client_str,db_str,coll_str)
        self.data = [e for e in self.collection.find({"_id":{"$in": batch_ids}})]


    @abstractmethod
    def popupStr_generator(self, df_row):
        pass

    @abstractmethod
    def tooltip_generator(self,df_row):
        pass

    @abstractmethod
    def gestalte_map(self):
        pass

    @abstractmethod
    def orderly_output(self):
        pass

# %% [markdown]
# ## OSM

# %%
class OSM_queryer(DBHandlers):

    def connect_db(self,Client=MongoClient,client_str='mongodb://localhost:27017', db_str='webscraping_dataLabKiel', coll_str='osm_data'):
        return super().connect_db(Client,client_str,db_str,coll_str)


    def design_query_dict(self,input):
        query_terms = []

        if "what" in input.keys():
            for val in input["what"]:
                query_terms.append({"name":{ "$regex": rf"^{val}", "$options": "i" }})
                query_terms.append({"amenity": { "$regex": rf"^{val}", "$options": "i" }})

        if "all" in input.keys():
            query_terms = super().design_query_dict()


        if "by_ids" in input.keys():
            query_terms.append({"_id":{"$in": input["by_ids"]}})

        #for returning nothing
        if query_terms == []:
            query_terms.append({"_id":"thisisanimpossibleid"}) #so that if nothing is entered nothing will be returned instead of everything
                

        self.query_dict = {"$or":query_terms}


    def retrieve_data(self, **kwargs):
        return super().retrieve_data()


    def check_click_radius(self, click_point, radius, data):
        return super().check_click_radius(click_point, radius, data)
    

    def no_duplicates(self, dict_list, new_dicts, key):
        return super().no_duplicates(dict_list, new_dicts, key)


    def popupStr_generator(self, df_row):
        try:
            name = f"<b>{df_row['name']}</b><br><br>"
            amenity = f"<i>amenity:</i>: {df_row['amenity']}"
            pps = name + amenity
            return pps
        except:
            pass

    def tooltip_generator(self,row):
        tts = ""
        try:
            tts = row['name']
            return tts
        except:
            pass
        return tts

    def gestalte_map(self,map,data):
        poi_df = pd.DataFrame(data) 
        try:    
            poi_df["lat"] = pd.to_numeric(poi_df["lat"])
            poi_df["lon"] = pd.to_numeric(poi_df["lon"])
            #poi_df.dropna(subset=["lat","lon"],inplace=True)

            for _, row in poi_df.iterrows():
                folium.Marker(
                    location=[row['lat'], row['lon']],
                    popup=self.popupStr_generator(row),
                    tooltip=self.tooltip_generator(row),
                    icon=folium.Icon(color="gray")
                ).add_to(map)
            return map
        except:
            #print("no map available due to e.g. naming errors")
            return map
        
    def display_output(self,map,data):
        self.gestalte_map(map=map,data=data)

    def click_polygon(self, click_point, data):
        return super().click_polygon(click_point, data)
    
    def plot_polygon(self,polygons,map):
        #add county area
        gdf = gpd.GeoDataFrame(polygons, geometry='geometry')
        gdf.set_crs(epsg=4326, inplace=True)
        for _,row in gdf.iterrows():
            sim_geo = gpd.GeoSeries(row["geometry"]).simplify(tolerance=0.001)
            geo_j = sim_geo.to_json()
            geo_j = folium.GeoJson(data=geo_j, style_function=lambda x: {"fillColor": "lightgray"})
            folium.Popup(row["name"]).add_to(geo_j)
            geo_j.add_to(map)

        #add rent markers
        self.display_output(map=map,data=self.results)

        return map


    def orderly_output(self, data):
        output = []
        for df_row in data:
            doc = {"name":df_row['name'], 
                   "amenity":df_row['amenity']}
            output.append(doc)
        return output 
    
    def retrieve_by_id(self, Client, client_str, db_str, coll_str, batch_ids):
        return super().retrieve_by_id(Client, client_str, db_str, coll_str, batch_ids)

# %% [markdown]
# ## YELLOW PAGES

# %%
class YP_queryer(DBHandlers):

    def connect_db(self,Client=MongoClient,client_str='mongodb://localhost:27017', db_str='sh_data_collection', coll_str='yp_kiel'):
        return super().connect_db(Client,client_str,db_str,coll_str)

    def design_query_dict(self, input):
        query_terms = []

        if "what" in input.keys():
                for val in input["what"]:
                        query_terms.append({"name":{ "$regex": rf"^{val}", "$options": "i" }})
                        query_terms.append({"keywords":{ "$regex": rf"^{val}", "$options": "i" }})

        if "all" in input.keys():
              query_terms = super().design_query_dict()

        if "by_ids" in input.keys():
            query_terms.append({"_id":{"$in": input["by_ids"]}})

        if query_terms == []:
                query_terms.append({"_id":"thisisanimpossibleid"}) #so that if nothing is entered nothing will be returned instead of everything
                
        self.query_dict = {"$or":query_terms}
    
    def retrieve_data(self):
        self.data = [elem for elem in self.collection.find(self.query_dict)]

    def time_check(self,time):
        mapping = {"Mo": ["Montag", "montag", "Mo", "mo", "Monday", "monday"],
                    "Di": ["Dienstag", "dienstag", "Tu", "tu", "Tuesday", "tuesday"],
                    "Mi": ["Mittwoch", "mittwoch", "We", "we", "Wednesday", "wednesday"],
                    "Do": ["Donnerstag", "donnerstag", "Th", "th", "Thursday", "thursday"],
                    "Fr": ["Freitag", "freitag", "Fr", "fr", "Friday", "friday"],
                    "Sa": ["Samstag", "samstag", "Sa", "sa", "Saturday", "saturday"],
                    "So": ["Sonntag", "sonntag", "Su", "su", "Sunday", "sunday"],
                }
        for k,v in mapping.items():
            if time in v:
                return k
        else:
            return None


    #add this!!!
    def within_time(self,data,date):
        if date=="today":
            date = pd.to_datetime(date,dayfirst=True).date() 
            #date = date.strftime("%Y-%m-%d")  
            date = date.strftime("%A") #yields weekday
        elif date == "tomorrow":
            date = pd.to_datetime("today").date()
            date = date + timedelta(days=1)
            #date = date.strftime("%Y-%m-%d")  
            date = date.strftime("%A")
        else:
            try:
                date = pd.to_datetime(date,dayfirst=True).date() #just make normal string date into correct format
                date = date.strftime("%A") #but still get weekday
            except ValueError:
                pass #if its not a date string, then maybe its like monday etc already
        time = self.time_check(date) #now get format to check opening hours, so Mo, Di, Mi etc
        results = []
        for e in data:
            opening_hours = e.get("openingHours")
            if opening_hours is not None:
                if any([k for k in opening_hours if time in k]):
                    results.append(e)
            else:
                #results.append(e)
                pass
        self.results = results
        return results


    def check_click_radius(self, click_point, radius, data):
        return super().check_click_radius(click_point, radius, data)
    
    
    def no_duplicates(self, dict_list, new_dicts, key):
        return super().no_duplicates(dict_list, new_dicts, key)


    # PLOTS
    def popupStr_generator(self, df_row):
        try:
            name = f"<b>{df_row['name']}</b><br><br>"
            link = f"<i>link:</i>: <a href='{df_row['sameAs']}'>{df_row['sameAs']}</a><br>"
            tel = f"<i>tel.:</i> {df_row['telephone']}<br>"
            address = df_row["address"]
            try:
                address = address["streetAddress"] + ", " + address["postalCode"] + ", " + address["addressLocality"]
            except:
                pass
            addr = f"<i>address:</i> {address}<br>"
            pps = name + link + tel + addr 
            return pps
        except:
            pass

    def tooltip_generator(self,row):
        tts = ""
        try:
            tts = row['name']
            return tts
        except:
            pass
        return tts

    def gestalte_map(self,map,data):
        poi_df = pd.DataFrame(data) 
        try:    
            poi_df["lat"] = pd.to_numeric(poi_df["lat"])
            poi_df["lon"] = pd.to_numeric(poi_df["lon"])
            #poi_df.dropna(subset=["lat","lon"],inplace=True)

            for _, row in poi_df.iterrows():
                folium.Marker(
                    location=[row['lat'], row['lon']],
                    popup=self.popupStr_generator(row),
                    tooltip=self.tooltip_generator(row),
                    icon=folium.Icon(color="beige")
                ).add_to(map)
            return map
        except:
            #print("no map available due to e.g. naming errors")
            return map
            
    def display_output(self,map,data):
        self.gestalte_map(map=map,data=data) 

    def click_polygon(self, click_point, data):
         return super().click_polygon(click_point, data)

    def plot_polygon(self,polygons,map):
        #add county area
        gdf = gpd.GeoDataFrame(polygons, geometry='geometry')
        gdf.set_crs(epsg=4326, inplace=True)
        for _,row in gdf.iterrows():
            sim_geo = gpd.GeoSeries(row["geometry"]).simplify(tolerance=0.001)
            geo_j = sim_geo.to_json()
            geo_j = folium.GeoJson(data=geo_j, style_function=lambda x: {"fillColor": "lightgrey"})
            folium.Popup(row["name"]).add_to(geo_j)
            geo_j.add_to(map)

        #add rent markers
        self.display_output(map=map,data=self.results)

        return map

    def orderly_output(self, data):
        output = []
        for df_row in data:
            address = df_row["address"]
            try:
                nice_address = address["streetAddress"] + ", " + address["postalCode"] + ", " + address["addressLocality"]
                address = f"<i>address:</i> {nice_address}<br>"
            except:
                pass
            try:
                name = df_row['name']
            except:
                name = None
            try:
                tel = df_row['telephone']
            except:
                tel = None
            try:
                hours = df_row["openingHours"]
            except:
                hours = None

            doc = {"name":name, 
                   "tel":tel,
                   "address":address,
                   "open":hours}
            output.append(doc)
        return output 
    

    def retrieve_by_id(self, Client, client_str, db_str, coll_str, batch_ids):
        return super().retrieve_by_id(Client, client_str, db_str, coll_str, batch_ids)

# %% [markdown]
# ## RENT

# %%
class RENT_queryer(DBHandlers):

    def connect_db(self,Client=MongoClient,client_str='mongodb://localhost:27017', db_str='webscraping_dataLabKiel', coll_str='rent_data'):
        return super().connect_db(Client,client_str,db_str,coll_str)

    def design_query_dict(self, input):
        query_terms = []

        if "rent" in input.keys():
                #query_terms = super().design_query_dict() #get everything
                query_terms = [{"collected":"True"}]

        if "what" in input.keys():
            for val in input["what"]:
                if val in ["rent","rents","miete","Miete"]:
                    query_terms = query_terms = [{"collected":"True"}]

        if "all" in input.keys():
              #query_terms = super().design_query_dict()
              query_terms = [{"collected":"True"}]

        if "by_ids" in input.keys():
            query_terms.append({"_id":{"$in": input["by_ids"]}})

        if query_terms == []:
                query_terms.append({"_id":"thisisanimpossibleid"}) #so that if nothing is entered nothing will be returned instead of everything
                
        self.query_dict = {"$or":query_terms}
    

    def retrieve_data(self):
        self.data = [elem for elem in self.collection.find(self.query_dict)]

    
    def check_click_radius(self, click_point, radius, data):
        return super().check_click_radius(click_point, radius, data)


    def no_duplicates(self, dict_list, new_dicts, key):
        return super().no_duplicates(dict_list, new_dicts, key)


    def tooltip_generator(self,row):
        tts = ""
        try: 
            tts = f"{row["average_rent"]}€ m²"
            return tts
        except:
            pass
        return tts

    def popupStr_generator(self,df_row):
        try:
            if df_row["Landkreis"] != []:
                name = f"<b>{df_row['Landkreis']}</b><br><br>"
            else:
                name = f"<b>{df_row['Stadt']}</b><br><br>"
            plz = f"<i>postcode:</i> {df_row['PLZ']}<br>"
            rent = f"<i>rent:</i> {df_row['average_rent']}€ per m²"
            pps = name + plz + rent
            return pps
        except:
            pass

        #so make sure data has no duplicates and all the naming is the same
    def gestalte_map(self,map,data):
        poi_df = pd.DataFrame(data) #compile business sample into df
        try:    
            median_rent = poi_df.average_rent.mean()
            poi_df["rent_ratio"] = poi_df.average_rent.apply(lambda x: "high" if x > median_rent else "low")
            high_rents = poi_df[poi_df["rent_ratio"]=="high"]
            for _, row in high_rents.iterrows():
                folium.Marker(
                    location=[row['lat'], row['lon']],
                    popup=self.popupStr_generator(row),
                    tooltip=self.tooltip_generator(row),
                    icon=folium.Icon(color="lightred")
                ).add_to(map)
            low_rents = poi_df[poi_df["rent_ratio"]=="low"]
            for _, row in low_rents.iterrows():
                folium.Marker(
                    location=[row['lat'], row['lon']],
                    popup=self.popupStr_generator(row),
                    tooltip=self.tooltip_generator(row),
                    icon=folium.Icon(color="lightblue")
                ).add_to(map)
            return map
        except:
            #print("no map available due to e.g. naming errors")
            return map

            
    def display_output(self,map,data):
        self.gestalte_map(map=map,data=data) #z is level of zoom

    def click_polygon(self, click_point, data):
        return super().click_polygon(click_point, data)
    
    def plot_polygon(self,polygons,map):
        #add county area
        gdf = gpd.GeoDataFrame(polygons, geometry='geometry')
        gdf.set_crs(epsg=4326, inplace=True)
        for _,row in gdf.iterrows():
            sim_geo = gpd.GeoSeries(row["geometry"]).simplify(tolerance=0.001)
            geo_j = sim_geo.to_json()
            geo_j = folium.GeoJson(data=geo_j, style_function=lambda x: {"fillColor": "lightgray"})
            folium.Popup(row["name"]).add_to(geo_j)
            geo_j.add_to(map)

        #add rent markers
        self.display_output(map=map,data=self.results)

        return map
        


    def orderly_output(self, data):
        output = []
        for df_row in data:
            doc = {"county":df_row["Landkreis"],
                   "city":df_row['Stadt'],
                   "postcode":df_row['PLZ'],
                   "avgerage rent":df_row['average_rent']}
            output.append(doc)
        return output 
    

    def retrieve_by_id(self, Client, client_str, db_str, coll_str, batch_ids):
        return super().retrieve_by_id(Client, client_str, db_str, coll_str, batch_ids)

# %% [markdown]
# ## EVENTS

# %%
class EVENT_queryer(DBHandlers):

    def connect_db(self,Client=MongoClient,client_str='mongodb://localhost:27017', db_str='webscraping_dataLabKiel', coll_str='event_data'):
        return super().connect_db(Client,client_str,db_str,coll_str)

    def design_query_dict(self, input):
        query_terms = []

        if "what" in input.keys():
            for val in input["what"]:
                query_terms.append({"title":{ "$regex": rf"^{val}", "$options": "i" }})
                query_terms.append({"categories":{ "$regex": rf"^{val}", "$options": "i" }})
                if val in ["event","events","Event","Events"]:
                    query_terms = super().design_query_dict()


        if "event" in input.keys():
            if input["event"] == True:
                query_terms = super().design_query_dict()
            #else:
                #query_terms = query_terms = super().design_query_dict()
                #check if collected events are at the relevant time or sth

        if "all" in input.keys():
            query_terms = super().design_query_dict()

        if "by_ids" in input.keys():
            query_terms.append({"_id":{"$in": input["by_ids"]}})

        if query_terms == []:
            query_terms.append({"_id":"thisisanimpossibleid"}) #so that if nothing is entered nothing will be returned instead of everything
                
        self.query_dict = {"$or":query_terms}
    

    def retrieve_data(self):
        self.data = [elem for elem in self.collection.find(self.query_dict)]

    
    def check_click_radius(self, click_point, radius, data):
        return super().check_click_radius(click_point, radius, data)


    def no_duplicates(self, dict_list, new_dicts, key):
        return super().no_duplicates(dict_list, new_dicts, key)
    
    def within_time(self,data,date):
        if date=="today":
            date = pd.to_datetime(date,dayfirst=True).date() 
            #date = date.strftime("%Y-%m-%d")  
        elif date == "tomorrow":
            date = pd.to_datetime("today").date()
            date = date + timedelta(days=1)
            #date = date.strftime("%Y-%m-%d")  
        else:
            try:
                date = pd.to_datetime(date,dayfirst=True).date()
            except ValueError:
                print("check your time format")
        results = []
        for e in data:
            if e.get("timeIntervals") is not None:
                ongoing = e.get("timeIntervals")
                ongoing = ongoing[0]
                #date = pd.to_datetime(date,dayfirst=True,format="%Y-%m-%d").date()
                #print(type(start),type(end),type(date))
                start, end = pd.to_datetime(ongoing["start"]).date(), pd.to_datetime(ongoing["end"]).date()
                if start <= date <= end:
                    results.append(e)
                else:
                    #results.append(e)
                    pass
        self.results = results
        return results
    

    # PLOTS
    def popupStr_generator(self, df_row):
        try:
            name = f"<b>{df_row['title']}</b><br><br>"
            link = f"<i>link:</i>: <a href='{df_row['source.url']}'>{df_row['source.url']}</a><br>"
            tel = f"<i>tel.:</i> {df_row['phone']}<br>"
            try:
                street = df_row["street"]
            except:
                street = ""
            try:
                city = df_row["city"] 
            except:
                city = ""
            try:
                zip = df_row["zip"]
            except:
                zip = None
            nice_addr = street + ", " + city + ", " + zip
            addr = f"<i>address:</i> {nice_addr}<br>"
            event_type = df_row['categories']
            separator = ", " 
            event_cat = separator.join(event_type)
            cat = f"<i>event type:</i> {event_cat}<br>"
            pps = name + link + tel + cat + addr 
            return pps
        except:
            pass

    def tooltip_generator(self,row):
        tts = ""
        try:
            tts = row['title']
            return tts
        except:
            pass
        return tts

    def gestalte_map(self,map,data):
        poi_df = pd.DataFrame(data) 
        try:    
            poi_df["lat"] = pd.to_numeric(poi_df["lat"])
            poi_df["lon"] = pd.to_numeric(poi_df["lon"])
            #poi_df.dropna(subset=["lat","lon"],inplace=True)

            for _, row in poi_df.iterrows():
                folium.Marker(
                    location=[row['lat'], row['lon']],
                    popup=self.popupStr_generator(row),
                    tooltip=self.tooltip_generator(row),
                    icon=folium.Icon(color="purple")
                ).add_to(map)
            return map
        except:
            #print("no map available due to e.g. naming errors")
            return map
            
    def display_output(self,map,data):
        self.gestalte_map(map=map,data=data) 


    def click_polygon(self, click_point, data):
        return super().click_polygon(click_point, data)
    
    def plot_polygon(self,polygons,map):
        #add county area
        gdf = gpd.GeoDataFrame(polygons, geometry='geometry')
        gdf.set_crs(epsg=4326, inplace=True)
        for _,row in gdf.iterrows():
            sim_geo = gpd.GeoSeries(row["geometry"]).simplify(tolerance=0.001)
            geo_j = sim_geo.to_json()
            geo_j = folium.GeoJson(data=geo_j, style_function=lambda x: {"fillColor": "lightgray"})
            folium.Popup(row["name"]).add_to(geo_j)
            geo_j.add_to(map)

        #add rent markers
        self.display_output(map=map,data=self.results)

        return map

    def orderly_output(self, data):
        output = []
        for df_row in data:
            try:
                street = df_row["street"]
            except:
                street = ""
            try:
                city = df_row["city"] 
            except:
                city = ""
            try:
                zip = df_row["zip"]
            except:
                zip = None
            nice_addr = street + ", " + city + ", " + zip
            doc = {"name":df_row["name"],
                   "tel":df_row['phone'],
                   "address":nice_addr,
                   "time":df_row['timeIntervals']}
            output.append(doc)
        return output 
    

    def retrieve_by_id(self, Client, client_str, db_str, coll_str, batch_ids):
        return super().retrieve_by_id(Client, client_str, db_str, coll_str, batch_ids)

# %% [markdown]
# ## NATURAL AREAS

# %%
class DIGITIZEDPLANET_queryer(DBHandlers):


    #CONNECT TO DB - COLLECTION
    def connect_db(self,Client=MongoClient,client_str='mongodb://localhost:27017', db_str='webscraping_dataLabKiel', coll_str='area_data'):
        return super().connect_db(Client,client_str,db_str,coll_str)

    #GET QUERY DICTIONARY FOR SEARCH
    def design_query_dict(self, input):
        query_terms = []

        if "what" in input.keys():
            for e in input["what"]:
                if e in ["nature","Natur","natural area","protected area","naturschutzgebiet","park"]:
                    query_terms = super().design_query_dict()

        if "all" in input.keys():
            query_terms = super().design_query_dict()

        if "by_ids" in input.keys():
            query_terms.append({"_id":{"$in": input["by_ids"]}})

        if query_terms == []:
            query_terms.append({"_id":"thisisanimpossibleid"}) #so that if nothing is entered nothing will be returned instead of everything
                
        self.query_dict = {"$or":query_terms}
    
    #RETRIEVE DATA BASED ON QUERY DICT
    def retrieve_data(self):
        self.data = [elem for elem in self.collection.find(self.query_dict)]

    
    #FILTER DATA BASED ON`RADIUS`
    def check_click_radius(self, click_point, radius, data):
        return super().check_click_radius(click_point, radius, data)
    

    def no_duplicates(self, dict_list, new_dicts, key):
        return super().no_duplicates(dict_list, new_dicts, key)


    # PLOTS
    def popupStr_generator(self, df_row):
        try:
            name = f"<b>{df_row['name']}</b><br><br>"
            area = f"<i>area in m²:</i> {df_row['area']}<br>"
            geom_s = f"<i>source:</i> {df_row['geometry_source']}<br>"
            pps = name + area + geom_s
            return pps
        except:
            pass

    def tooltip_generator(self,row):
        tts = ""
        try:
            tts = row['name']
            return tts
        except:
            pass
        return tts

    def gestalte_map(self,map,data):
        poi_df = pd.DataFrame(data) 
        try:    
            for _, row in poi_df.iterrows():
                folium.Marker(
                    location=[row['lat'], row['lon']],
                    popup=self.popupStr_generator(row),
                    tooltip=self.tooltip_generator(row),
                    icon=folium.Icon(color="darkblue")
                ).add_to(map)
            return map
        except:
            #print("no map available due to e.g. naming errors")
            return map
                    

    def click_polygon(self, click_point, data):
        return super().click_polygon(click_point, data)

    def plot_area_polygon(self,map,data):
        try:
            poi_df = pd.DataFrame(data)
            poi_df["geometry"] = poi_df['geometry'].apply(shape)
            gdf = gpd.GeoDataFrame(poi_df, geometry='geometry')
            gdf.set_crs(epsg=4326, inplace=True)
            for _,row in gdf.iterrows():
                sim_geo = gpd.GeoSeries(row["geometry"]).simplify(tolerance=0.001)
                geo_j = sim_geo.to_json()
                geo_j = folium.GeoJson(data=geo_j, style_function=lambda x: {"fillColor": "darkblue"})
                folium.Popup(self.popupStr_generator(row)).add_to(geo_j)
                geo_j.add_to(map)
            
            gdf = gdf.to_crs(epsg=2263)
            gdf["centroid"] = gdf.centroid.to_crs(epsg=4326)
            for _, row in gdf.iterrows():
                lat = row["centroid"].y
                lon = row["centroid"].x
                folium.Marker(
                    location=[lat, lon],
                    popup=self.popupStr_generator(row),
                    tooltip=self.tooltip_generator(row),
                    icon=folium.Icon(color="darkblue")
                ).add_to(map)
            return map
        except:
            return map

    def plot_polygon(self,polygons,map):
        #add county area
        gdf = gpd.GeoDataFrame(polygons, geometry='geometry')
        gdf.set_crs(epsg=4326, inplace=True)
        for _,row in gdf.iterrows():
            sim_geo = gpd.GeoSeries(row["geometry"]).simplify(tolerance=0.001)
            geo_j = sim_geo.to_json()
            geo_j = folium.GeoJson(data=geo_j, style_function=lambda x: {"fillColor": "lightgray"})
            folium.Popup(row["name"]).add_to(geo_j)
            geo_j.add_to(map)

        #add areas & markers
        self.plot_area_polygon(map=map,data=self.results)

        return map
    
    def display_output(self,map,data):
        self.plot_area_polygon(map=map,data=data) 
        #bzw self.gestalte_map(map=map,data=data) 


    def orderly_output(self, data):
        output = []
        for df_row in data:
            doc = {"name":df_row["name"],
                   "area":df_row['area'],
                   "source":df_row['geometry_source']}
            output.append(doc)
        return output 
    
    def retrieve_by_id(self, Client, client_str, db_str, coll_str, batch_ids):
        return super().retrieve_by_id(Client, client_str, db_str, coll_str, batch_ids)

# %% [markdown]
# ## nlp search

# %%
class NLP_search(DBHandlers):


    #CONNECT TO DB - COLLECTION
    def connect_db(self,Client,embedding,collection,path):
        vectordb = Client(
            collection_name=collection,
            persist_directory=path,
            embedding_function=embedding
        )
        self.retriever = vectordb.as_retriever(search_kwargs=dict(k=20))
        return vectordb

    
    #RETRIEVE DATA BASED ON QUERY DICT
    def retrieve_data(self,input):
        #print(self.retriever)
        self.data = self.retriever.invoke(input) #HERE LIES THE ISSUE?
        #print(self.data)
        batch_ids = [ObjectId(r.metadata["mongo_id"]) for r in self.data]
        return batch_ids
    
        #GET QUERY DICTIONARY FOR SEARCH
    def design_query_dict(self):
        pass

    
    #FILTER DATA BASED ON`RADIUS`
    def check_click_radius(self, click_point, radius, data):
        pass
    
    def no_duplicates(self, dict_list, new_dicts, key):
        pass

    def popupStr_generator(self, df_row):
        pass

    def tooltip_generator(self, df_row):
        pass

    def gestalte_map(self,map,data):
        pass
                    
    def click_polygon(self, click_point, data):
        pass

    def plot_area_polygon(self,map,data):
        pass

    def plot_polygon(self,polygons,map):
        pass
    
    def display_output(self,map,data):
        pass


    def orderly_output(self, data):
        pass
    
    def retrieve_by_id(self, Client, client_str, db_str, coll_str, batch_ids):
        pass

# %% [markdown]
# # 2 output manager

# %% [markdown]
# ## OUTPUT MANAGER

# %%
class OutputManager():

    #make function which integrated but doesnt return data from all data bases!!!
    def disambiguate(self,queriers):    
        threshold = 80 #of similarity, selected by just trying it out
        temp = []

        #go through the returned (no duplicate) result list of every querier
        for q in queriers:
            querier_results = q.results #get data for the querier
            q.results = [] #empty slate for querier.results

            #as long as theres still names to check
            while querier_results != []:
                elem = querier_results.pop()
                try:
                    name = elem["name"]
                    possible_double = [k for k in temp if fuzz.token_set_ratio(name,k.get("name")) >= threshold] #retrieve similar names from temp result list
                    if len(possible_double) >= 1: #if some similar name(s) found
                        elem_loc = (elem["lat"],elem["lon"]) #get coordinates of original point which we want to add
                        the_same = False #assume they are not the same location
                        for pos_doub in possible_double:
                            pos_doub_loc = (pos_doub["lat"],pos_doub["lon"]) #get coordinates from matches from temporary result list
                            if geodesic(elem_loc,pos_doub_loc).km < 0.1: # if it turns out they are in same locations, so if they are more less 100m apart
                                the_same = True # flag: okay so actually we found a match, so something with a similar name less than 100 m away
                        if the_same==False: # only if we didnt find anything simlar at all
                            temp.append(elem) #append to temporary checking list
                            q.results.append(elem) #add to collection specific result bucket so we can pass it again to database handler for output
                    else: #if we dont have anything similar (yet) just stick it in there
                        temp.append(elem)
                        q.results.append(elem)
                except KeyError:
                    pass


    #return (filtered) search results 
    def initiate_search(self,Querier,query,key):
        q = Querier()
        q.connect_db()
        q.design_query_dict(query)
        q.retrieve_data()
        q.results = q.no_duplicates([],q.data,key)
        return q
    
    def unbounded_data(self,q,map):
        q.display_output(map=self.map,data=q.results)
        return map, q.results
    
    #get data within a certain radius
    def radius_data(self,q,map,point,radius):
        q.check_click_radius(click_point=point,radius=radius, data=q.results) 
        q.display_output(map=self.map,data=q.results)
        return map, q.results

    #get data within polygon (== county)
    def polygon_data(self,q,map,point):
        poly = q.click_polygon(click_point=point,data=q.results)
        q.plot_polygon(poly,map)
        return map, q.results

    # area is radius (e.g. 0.5) or "polygon"
    def process_query_click(self, querier_instance, area, point, map_object):
        if area == "polygon":
            return self.polygon_data(querier_instance, map_object, point)
        elif isinstance(area, (int, float)): #is radius essentially
            return self.radius_data(querier_instance, map_object, point, area)
        else:
            return self.unbounded_data(querier_instance, map_object)
        

    def perform_search(self,**kwargs):
        
        # click + filter 
        # click + empty filter: all 
        # no click + filter (so not area specific, neither radius nor polygon!!!) -> area = None

        #if "query" in kwargs and "point" in kwargs and "area" in kwargs:

        # SET UP: get arguments
        if "query" in kwargs and "point" in kwargs and "area" in kwargs:
            query, point, area = kwargs["query"], kwargs["point"], kwargs["area"]
            self.map = folium.Map(location=point,zoom_start=8) #one output object of output manager
        elif "query" in kwargs:
            query, point, area = kwargs["query"], None, None
            self.map = folium.Map(location=(54.2194,9.6961),zoom_start=6) #one output object of output manager

        # out of the query dict get the actual value
        time_search = False
        if query.get("time") is not None:
            time_search = True
            time = query.get("time")

        
        # INSTANTIATE QUERIERS (get data, apply no duplicate, get results per querier)
        self.querier_osm = self.initiate_search(OSM_queryer, query=query,key="")
        self.querier_yp = self.initiate_search(YP_queryer, query=query,key="name")
        self.querier_event = self.initiate_search(EVENT_queryer, query=query,key="")
        self.querier_rent = self.initiate_search(RENT_queryer, query=query,key="PLZ")
        self.querier_area = self.initiate_search(DIGITIZEDPLANET_queryer, query=query,key="name")

        # DISAMBIGUATE ALL DATA BY NAME SIMILARITY AND LOCATION
        queriers = [self.querier_yp,self.querier_osm,self.querier_event]
        self.disambiguate(queriers)

        # NOW CHECK TIMES 
        if time_search == True:
            #for yellow page easy, just check if result of time is helpful
            self.querier_yp.results = self.querier_yp.within_time(data=self.querier_yp.results,date=time)
            self.querier_event.results = self.querier_event.within_time(data=self.querier_event.results,date=time)
            self.querier_event.no_duplicates([],self.querier_event.results,key="title")

        # NOW PUT DATA ON MAP
        self.map, self.osm_data = self.process_query_click(self.querier_osm, area=area, point=point, map_object=self.map)
        self.map, self.yp_data = self.process_query_click(self.querier_yp, area=area, point=point, map_object=self.map)
        self.map, self.event_data = self.process_query_click(self.querier_event, area=area, point=point, map_object=self.map)
        self.map, self.rent_data = self.process_query_click(self.querier_rent, area=area, point=point, map_object=self.map)
        self.map, self.area_data = self.process_query_click(self.querier_area, area=area, point=point, map_object=self.map)

        # COMBINE ALL DATA
        #for all queriers now! nicefy data
        self.nice_data = self.querier_yp.orderly_output(data=self.yp_data) + self.querier_rent.orderly_output(data=self.rent_data) + self.querier_event.orderly_output(data=self.event_data) + self.querier_area.orderly_output(data=self.area_data) + self.querier_osm.orderly_output(data=self.osm_data)
        self.data = self.yp_data + self.osm_data + self.event_data + self.rent_data + self.area_data

    

    def nlp_search(self, **kwargs):
        if "nlp" in kwargs:
            input = kwargs["nlp"]
            nlp = NLP_search()
            vdb = nlp.connect_db(Chroma,HuggingFaceEmbeddings(model_name='sentence-transformers/all-MiniLM-L6-v2'),"nlp_search","./nlp_search")
            ids = nlp.retrieve_data(input)
            query = {"by_ids":ids}
            self.perform_search(query=query)

# %% [markdown]
# # 3 experiments handlers

# %% [markdown]
# ---
#
# ## Try it out: what can the datahandlers do?
#
# ---

# %% [markdown]
# ### osm 1

# %%
click_point = (54.3233,10.1228)
radius = 5
i = {"what":["pub"]}

cosm = OSM_queryer()
cosm.connect_db()
cosm.collection

cosm.design_query_dict(i)
print(cosm.query_dict)

cosm.retrieve_data()
results = cosm.data
print(f"len of result pre range filter: {len(results)}")

cosm.check_click_radius(click_point=click_point,radius=radius,data=results)
results = cosm.results
print(f"len of result post range filter: {len(results)}")

results_2 = cosm.no_duplicates([],results,key="name")
print(f"len of result duplicate filter: {len(results)}")

zoom = 8
my_map = folium.Map(location=click_point,zoom_start=zoom)
cosm.display_output(map=my_map,data=results)
#my_map
# Out:
# {'$or': [{'name': {'$regex': '^pub', '$options': 'i'}}, {'amenity': {'$regex': '^pub', '$options': 'i'}}]}
# len of result pre range filter: 611
# len of result post range filter: 58
# len of result duplicate filter: 58

# %% [markdown]
# ### osm 2

# %%
click_point = (54.43700, 11.12160)
i = {"what":["pub"]}

c = OSM_queryer()
c.connect_db()
c.collection

c.design_query_dict(i)
print(c.query_dict)

c.retrieve_data()
results = c.data
print(f"len of result pre range filter: {len(results)}")

poly = c.click_polygon(click_point=click_point,data=results)
results = c.results
print(f"len of result post range filter: {len(results)}")

zoom = 8
my_map = folium.Map(location=click_point,zoom_start=zoom)
my_map = c.plot_polygon(poly,map=my_map)
#my_map
# Out:
# {'$or': [{'name': {'$regex': '^pub', '$options': 'i'}}, {'amenity': {'$regex': '^pub', '$options': 'i'}}]}
# len of result pre range filter: 611
# len of result post range filter: 41

# %% [markdown]
# ### yellow pages 1

# %%
click_point = (54.3233,10.1228)
radius = 1
i = {"what":["friseur"]}


c = YP_queryer()
#c.connect_db(db_str="webscraping_dataLabKiel",coll_str="yellow_pages")
c.connect_db()
print(c.collection)

c.design_query_dict(i)
print(c.query_dict)

c.retrieve_data()
results = c.data
print(f"len of result pre range filter: {len(results)}")

c.check_click_radius(click_point=click_point,radius=radius,data=results)
results = c.results
print(f"len of result post range filter: {len(results)}")

results = c.no_duplicates([],results,key="name")
print(f"len of result duplicate filter: {len(results)}")

results = c.within_time(data=c.results,date="03.12.2024")
print(f"len of result time filter: {len(c.results)}")

zoom = 8
my_map = folium.Map(location=click_point,zoom_start=zoom)
c.display_output(map=my_map,data=results)
#cosm.display_output(map=my_map,data=results_2)
my_map
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'sh_data_collection'), 'yp_kiel')
# {'$or': [{'name': {'$regex': '^friseur', '$options': 'i'}}, {'keywords': {'$regex': '^friseur', '$options': 'i'}}]}
# len of result pre range filter: 41
# len of result post range filter: 12
# len of result duplicate filter: 9
# len of result time filter: 6
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ac56afe0783f5f71dedc5456ef28fe6f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ac56afe0783f5f71dedc5456ef28fe6f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ac56afe0783f5f71dedc5456ef28fe6f = L.map(
#                 &quot;map_ac56afe0783f5f71dedc5456ef28fe6f&quot;,
#                 {
#                     center: [54.3233, 10.1228],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3b4b0a0c279dc3beb51825526eead8ee = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3b4b0a0c279dc3beb51825526eead8ee.addTo(map_ac56afe0783f5f71dedc5456ef28fe6f);
#
#
#             var marker_9b8666f5688052447ab06dbc3d036247 = L.marker(
#                 [54.317303, 10.132873],
#                 {}
#             ).addTo(map_ac56afe0783f5f71dedc5456ef28fe6f);
#
#
#             var icon_b35155ab8add85c3b98b65f78d81c553 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9b8666f5688052447ab06dbc3d036247.setIcon(icon_b35155ab8add85c3b98b65f78d81c553);
#
#
#         var popup_5ee8e0306da264a495f94430fe97475d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ef5c1f723a6b76e779261f82c8c74ed6 = $(`&lt;div id=&quot;html_ef5c1f723a6b76e779261f82c8c74ed6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Friseur Marion Mahlich Jolanthe Garbiec GbR Friseurbetrieb&lt;/b&gt;&lt;br&gt;&lt;br&gt;&lt;i&gt;link:&lt;/i&gt;: &lt;a href=&#x27;http://www.friseur-mahlich.de&#x27;&gt;http://www.friseur-mahlich.de&lt;/a&gt;&lt;br&gt;&lt;i&gt;tel.:&lt;/i&gt; 0431 6 35 58&lt;br&gt;&lt;i&gt;address:&lt;/i&gt; Sophienblatt 11, 24103, Kiel&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_5ee8e0306da264a495f94430fe97475d.setContent(html_ef5c1f723a6b76e779261f82c8c74ed6);
#
#
#
#         marker_9b8666f5688052447ab06dbc3d036247.bindPopup(popup_5ee8e0306da264a495f94430fe97475d)
#         ;
#
#
#
#
#             marker_9b8666f5688052447ab06dbc3d036247.bindTooltip(
#                 `&lt;div&gt;
#                      Friseur Marion Mahlich Jolanthe Garbiec GbR Friseurbetrieb
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b370192ad2d984c385def2c0b4ff8736 = L.marker(
#                 [54.31771, 10.128552],
#                 {}
#             ).addTo(map_ac56afe0783f5f71dedc5456ef28fe6f);
#
#
#             var icon_9f457c737078be887a03cdc4da9ed888 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b370192ad2d984c385def2c0b4ff8736.setIcon(icon_9f457c737078be887a03cdc4da9ed888);
#
#
#         var popup_f8804d3a7b0b0113ca91ec7ac0889eee = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c59a4c2e9b84bb78596161641b415ba7 = $(`&lt;div id=&quot;html_c59a4c2e9b84bb78596161641b415ba7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;White &amp; Black Styling Lounge Inh. Fredda und Mohamed Traore&lt;/b&gt;&lt;br&gt;&lt;br&gt;&lt;i&gt;link:&lt;/i&gt;: &lt;a href=&#x27;http://www.white-black-styling-lounge.de&#x27;&gt;http://www.white-black-styling-lounge.de&lt;/a&gt;&lt;br&gt;&lt;i&gt;tel.:&lt;/i&gt; 0431 88 90 05 90&lt;br&gt;&lt;i&gt;address:&lt;/i&gt; Königsweg 1, 24103, Kiel&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_f8804d3a7b0b0113ca91ec7ac0889eee.setContent(html_c59a4c2e9b84bb78596161641b415ba7);
#
#
#
#         marker_b370192ad2d984c385def2c0b4ff8736.bindPopup(popup_f8804d3a7b0b0113ca91ec7ac0889eee)
#         ;
#
#
#
#
#             marker_b370192ad2d984c385def2c0b4ff8736.bindTooltip(
#                 `&lt;div&gt;
#                      White &amp; Black Styling Lounge Inh. Fredda und Mohamed Traore
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ed0f2840fdb57e8445f06c9fa866dce2 = L.marker(
#                 [54.322117, 10.136196],
#                 {}
#             ).addTo(map_ac56afe0783f5f71dedc5456ef28fe6f);
#
#
#             var icon_e26e8aa88f54922b26387d08e83b9080 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &

# %% [markdown]
# ### yellow pages 2

# %%
click_point = (54.3233,10.1228)
i = {"what":["friseur"]}

c = YP_queryer()
#c.connect_db(db_str="webscraping_dataLabKiel",coll_str="yellow_pages")
c.connect_db()
print(c.collection)

c.design_query_dict(i)
print(c.query_dict)

c.retrieve_data()
results = c.data
print(f"len of result pre range filter: {len(results)}")

poly = c.click_polygon(click_point=click_point,data=results)
results = c.results
print(f"len of result post range filter: {len(results)}")

zoom = 8
my_map = folium.Map(location=click_point,zoom_start=zoom)
my_map = c.plot_polygon(poly,map=my_map)
#my_map
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'sh_data_collection'), 'yp_kiel')
# {'$or': [{'name': {'$regex': '^friseur', '$options': 'i'}}, {'keywords': {'$regex': '^friseur', '$options': 'i'}}]}
# len of result pre range filter: 41
# len of result post range filter: 33

# %% [markdown]
# ### rent

# %%
click_point = (54.323334, 10.139444)
radius = 25
i = {"rent":True}

c = RENT_queryer()
c.connect_db()
c.collection

c.design_query_dict(i)
print(c.query_dict)

c.retrieve_data()
results = c.data
print(f"len of result pre range filter: {len(results)}")

c.check_click_radius(click_point=click_point,radius=radius,data=results)
results = c.data
print(f"len of result post range filter: {len(results)}")

results = c.no_duplicates([],results,key="PLZ")
print(f"len of result duplicate filter: {len(results)}")

zoom = 8
my_map = folium.Map(location=click_point,zoom_start=zoom)
my_map = c.display_output(map=my_map,data=results)
# my_map
# Out:
# {'$or': [{'collected': 'True'}]}
# len of result pre range filter: 386
# len of result post range filter: 386
# len of result duplicate filter: 381

# %% [markdown]
# ### rent 2

# %%
coordinates = [
    (54.51450, 8.86610),  # Nordfriesland
    (54.17230, 9.03890),  # Dithmarschen
    (54.36980, 9.73560),  # Rendsburg-Eckernförde
    (54.71020, 9.41230),  # Schleswig-Flensburg
    (54.20840, 10.41490), # Plön
    (54.17650, 10.93020), # Ostholstein
    (53.67620, 9.66230),  # Pinneberg
    (53.91540, 10.25580), # Segeberg
    (53.70010, 10.39460)  # Stormarn
]

# %%
click_point =  (54.17230, 9.03890)
i = {"rent":True}

c = RENT_queryer()
c.connect_db()
c.collection

c.design_query_dict(i)
print(c.query_dict)

c.retrieve_data()
results = c.data
print(f"len of result pre range filter: {len(results)}")

poly = c.click_polygon(click_point=click_point,data=results)
results = c.results
print(f"len of result post range filter: {len(results)}")

results = c.no_duplicates([],results,key="PLZ")
print(f"len of result duplicate filter: {len(results)}")

zoom = 8
my_map = folium.Map(location=click_point,zoom_start=zoom)
#c.plot_polygon(poly,map=my_map,data=results)
# Out:
# {'$or': [{'collected': 'True'}]}
# len of result pre range filter: 386
# len of result post range filter: 17
# len of result duplicate filter: 17

# %% [markdown]
# ### events 1

# %%
click_point = (54.323334, 10.139444)
radius = 2
i = {"what":["kultur","kunst","ausstellung"]}

c = EVENT_queryer()
c.connect_db()
c.collection

c.design_query_dict(i)
print(c.query_dict)

c.retrieve_data()
results = c.data
print(f"len of result pre range filter: {len(results)}")

c.check_click_radius(click_point=click_point,radius=radius,data=results)
print(f"len of result post range filter: {len(c.results)}")

c.within_time(data=c.results,date="01.12.2024")
print(f"len of result post date filter: {len(c.results)}")

c.results = c.no_duplicates([],c.results,key="title")
print(f"len of result duplicate filter: {len(c.results)}")

zoom = 8
my_map = folium.Map(location=click_point,zoom_start=zoom)
c.display_output(map=my_map,data=c.results)
my_map
# Out:
# {'$or': [{'title': {'$regex': '^kultur', '$options': 'i'}}, {'categories': {'$regex': '^kultur', '$options': 'i'}}, {'title': {'$regex': '^kunst', '$options': 'i'}}, {'categories': {'$regex': '^kunst', '$options': 'i'}}, {'title': {'$regex': '^ausstellung', '$options': 'i'}}, {'categories': {'$regex': '^ausstellung', '$options': 'i'}}]}
# len of result pre range filter: 1625
# len of result post range filter: 1179
# len of result post date filter: 25
# len of result duplicate filter: 10
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0a9c4e0c0cf754d808dc9f18fe4e65f8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0a9c4e0c0cf754d808dc9f18fe4e65f8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0a9c4e0c0cf754d808dc9f18fe4e65f8 = L.map(
#                 &quot;map_0a9c4e0c0cf754d808dc9f18fe4e65f8&quot;,
#                 {
#                     center: [54.323334, 10.139444],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f57e8fd946d0b6e2fe33ea325f0460ea = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f57e8fd946d0b6e2fe33ea325f0460ea.addTo(map_0a9c4e0c0cf754d808dc9f18fe4e65f8);
#
#
#             var marker_d64fc70be6f679085608b3b14283b43e = L.marker(
#                 [54.3150713111, 10.1347160339],
#                 {}
#             ).addTo(map_0a9c4e0c0cf754d808dc9f18fe4e65f8);
#
#
#             var icon_17751b683f594bc61bc2a5279bdff902 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d64fc70be6f679085608b3b14283b43e.setIcon(icon_17751b683f594bc61bc2a5279bdff902);
#
#
#         var popup_61624c0750e940955e3654fe5176b9f6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7b1d659d657ddf7d25b8360410a8f203 = $(`&lt;div id=&quot;html_7b1d659d657ddf7d25b8360410a8f203&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Tagesfahrt auf dem Raddampfer Freya mit Besuch des Weihnachtsmarktes Gut Steinwehr&lt;/b&gt;&lt;br&gt;&lt;br&gt;&lt;i&gt;link:&lt;/i&gt;: &lt;a href=&#x27;http://destination.one/&#x27;&gt;http://destination.one/&lt;/a&gt;&lt;br&gt;&lt;i&gt;tel.:&lt;/i&gt; None&lt;br&gt;&lt;i&gt;event type:&lt;/i&gt; Gastronomie, Kultur, Märkte, Regionale Spezialitäten&lt;br&gt;&lt;i&gt;address:&lt;/i&gt; Bahnhofsbrücke, Kiel, 24114&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_61624c0750e940955e3654fe5176b9f6.setContent(html_7b1d659d657ddf7d25b8360410a8f203);
#
#
#
#         marker_d64fc70be6f679085608b3b14283b43e.bindPopup(popup_61624c0750e940955e3654fe5176b9f6)
#         ;
#
#
#
#
#             marker_d64fc70be6f679085608b3b14283b43e.bindTooltip(
#                 `&lt;div&gt;
#                      Tagesfahrt auf dem Raddampfer Freya mit Besuch des Weihnachtsmarktes Gut Steinwehr
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d378d3bbbe569d31d4599a73562add26 = L.marker(
#                 [54.31531955, 10.153037018],
#                 {}
#             ).addTo(map_0a9c4e0c0cf754d808dc9f18fe4e65f8);
#
#
#             var icon_89ac0eb9e92d6e72a133ab9992247231 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d378d3bbbe569d31d4599a73562add26.setIcon(icon_89ac0eb9e92d6e72a133ab9992247231);
#
#
#         var popup_7aec5f3e24a4bab379e51cfff8807d42 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f3f363a8722557b9c0647836ec5ef22d = $(`&lt;div id=&quot;html_f3f363a8722557b9c0647836ec5ef22d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Kleiner Kunstmarkt &lt;/b&gt;&lt;br&gt;&lt;br&gt;&lt;i&gt;link:&lt;/i&gt;: &lt;a href=&#x27;http://destination.one/&#x27;&gt;http://destination.one/&lt;/a&gt;&lt;br&gt;&lt;i&gt;tel.:&lt;/i&gt; 0431 28935016&lt;br&gt;&lt;i&gt;event type:&lt;/i&gt; Märkte, Kultur&lt;br&gt;&lt;i&gt;address:&lt;/i&gt; Kaiserstraße 4, Kiel, 24143&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_7aec5f3e24a4bab379e51cfff8807d42.setContent(html_f3f363a8722557b9c0647836ec5ef22d);
#
#
#
#         marker_d378d3bbbe569d31d4599a73562add26.bindPopup(popup_7aec5f3e24a4bab379e51cfff8807d42)
#         ;
#
#
#
#
#             marker_d378d3bbbe569d31d4599a73562add26.bindTooltip(
#                 `&lt;div&gt;
#                      Kleiner Kunstmarkt
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_910ec3914130eba9aa65ad2d0ce506d3 = L.marker(
#                 [54.32253365, 10.1225085611],
#                 {}
#             ).addTo(map_0a9c4e0c0cf754d808dc9f18fe4e65f8);
#
#
#             var icon_2ad51ab443ba9b6ff0389d05dd740c1a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot

# %% [markdown]
# ### events 2

# %%
click_point = (54.323334, 10.139444)
i = {"what":["kunst","ausstellung"]}

c = EVENT_queryer()
c.connect_db()
c.collection

c.design_query_dict(i)
print(c.query_dict)

c.retrieve_data()
results = c.data
print(f"len of result pre range filter: {len(results)}")

poly = c.click_polygon(click_point=click_point,data=results)
results = c.results
print(f"len of result post range filter: {len(results)}")

results = c.no_duplicates([],results,key="title")
print(f"len of result duplicate filter: {len(results)}")

zoom = 8
my_map = folium.Map(location=click_point,zoom_start=zoom)
#c.plot_polygon(poly,map=my_map)
# Out:
# {'$or': [{'title': {'$regex': '^kunst', '$options': 'i'}}, {'categories': {'$regex': '^kunst', '$options': 'i'}}, {'title': {'$regex': '^ausstellung', '$options': 'i'}}, {'categories': {'$regex': '^ausstellung', '$options': 'i'}}]}
# len of result pre range filter: 482
# len of result post range filter: 349
# len of result duplicate filter: 16

# %% [markdown]
# ### natural areas 1

# %%
click_point = (54.323334, 10.139444)
radius = 19
i = {"all":True}

c = DIGITIZEDPLANET_queryer()
c.connect_db()
c.collection

c.design_query_dict(i)
print(c.query_dict)

c.retrieve_data()
results = c.data
print(f"len of result pre range filter: {len(results)}")

c.check_click_radius(click_point=click_point,radius=radius,data=results)
results = c.results
print(f"len of result post range filter: {len(results)}")

results = c.no_duplicates([],results,key="name")
print(f"len of result duplicate filter: {len(results)}")

zoom = 8
my_map = folium.Map(location=click_point,zoom_start=zoom)
c.display_output(map=my_map,data=results)
my_map
# Out:
# {'$or': [{}, {}]}
# len of result pre range filter: 17
# len of result post range filter: 10
# len of result duplicate filter: 10
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_22fefc12ff646993ed40d548e8bab8c9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_22fefc12ff646993ed40d548e8bab8c9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_22fefc12ff646993ed40d548e8bab8c9 = L.map(
#                 &quot;map_22fefc12ff646993ed40d548e8bab8c9&quot;,
#                 {
#                     center: [54.323334, 10.139444],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_44d651f1479a174c1faf7c8d7d809d1a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_44d651f1479a174c1faf7c8d7d809d1a.addTo(map_22fefc12ff646993ed40d548e8bab8c9);
#
#
#         function geo_json_859fcc681bdc82ff8175ca6aab50fd34_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillColor&quot;: &quot;darkblue&quot;};
#             }
#         }
#
#         function geo_json_859fcc681bdc82ff8175ca6aab50fd34_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json
, 54.2857215226782], [9.91143975863224, 54.2830468804759], [9.9142161405098, 54.2824642027376], [9.92059599529283, 54.2885145976152], [9.92994027769826, 54.2911784064906], [9.93790888385527, 54.2914139830186], [9.94566263748909, 54.2885678465289], [9.95379612604436, 54.2890921657377], [9.95192206266284, 54.2908548484667], [9.95103539245261, 54.2967119128428], [9.95289118418497, 54.3004520366538], [9.9552209

# %% [markdown]
# ### by id stuff 4

# %%
click_point = (54.323334, 10.139444)
radius = 19
i = {"by_ids":[ObjectId("673dbde749a3c34a323af430"),ObjectId("673dbe3d49a3c34a323af431")]}

c = DIGITIZEDPLANET_queryer()
c.connect_db()
c.collection

c.design_query_dict(i)
print(c.query_dict)

c.retrieve_data()
results = c.data
print(f"len of result pre range filter: {len(results)}")

c.check_click_radius(click_point=click_point,radius=radius,data=results)
results = c.results
print(f"len of result post range filter: {len(results)}")

results = c.no_duplicates([],results,key="name")
print(f"len of result duplicate filter: {len(results)}")

zoom = 8
my_map = folium.Map(location=click_point,zoom_start=zoom)
c.display_output(map=my_map,data=results)

#my_map
# Out:
# {'$or': [{'_id': {'$in': [ObjectId('673dbde749a3c34a323af430'), ObjectId('673dbe3d49a3c34a323af431')]}}]}
# len of result pre range filter: 2
# len of result post range filter: 2
# len of result duplicate filter: 2

# %% [markdown]
# ### natural areas 2 & 3

# %%
click_point = (54.323334, 10.139444)
radius = 50
i = {"what":["protected area"]}

c = DIGITIZEDPLANET_queryer()
c.connect_db()
c.collection

c.design_query_dict(i)
print(c.query_dict)

c.retrieve_data()
results = c.data
print(f"len of result pre range filter: {len(results)}")

c.check_click_radius(click_point=click_point,radius=radius,data=results)
results = c.results
print(f"len of result post range filter: {len(results)}")

results = c.no_duplicates([],results,key="name")
print(f"len of result duplicate filter: {len(results)}")

zoom = 8
my_map = folium.Map(location=click_point,zoom_start=zoom)
my_map = c.plot_area_polygon(map=my_map,data=results)
#my_map
# Out:
# {'$or': [{}, {}]}
# len of result pre range filter: 17
# len of result post range filter: 17
# len of result duplicate filter: 17

# %%
click_point = (54.36980, 9.73560)
i = {"what":["protected area"]}

c = DIGITIZEDPLANET_queryer()
c.connect_db()
c.collection

c.design_query_dict(i)
print(c.query_dict)

c.retrieve_data()
results = c.data
print(f"len of result pre range filter: {len(results)}")

poly = c.click_polygon(click_point=click_point,data=results)
results = c.results
print(f"len of result post polygon filter: {len(results)}")


zoom = 8
my_map = folium.Map(location=click_point,zoom_start=zoom)
my_map = c.plot_polygon(map=my_map,polygons=poly)
#my_map
# Out:
# {'$or': [{}, {}]}
# len of result pre range filter: 17
# len of result post polygon filter: 16

# %% [markdown]
# ----

# %% [markdown]
# # 4 experiments output manager

# %% [markdown]
# this returns osm and yp  and event data, <br> - fix the regex expressions, cause 'asia' returns 19 results, but 'asian' nothing

# %%
click_point = (54.323334, 10.139444)
radius = 5
i = {"what":["asia","karaoke","music"]} 

om = OutputManager()
om.perform_search(query=i,point=click_point,area=radius)
print(len(om.data))
#om.nice_data
om.map
# Out:
# 24
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_74dc110f6b9d19a8ba146488bbf047a9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_74dc110f6b9d19a8ba146488bbf047a9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_74dc110f6b9d19a8ba146488bbf047a9 = L.map(
#                 &quot;map_74dc110f6b9d19a8ba146488bbf047a9&quot;,
#                 {
#                     center: [54.323334, 10.139444],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0f61a98e12daecada278e55c017332ba = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0f61a98e12daecada278e55c017332ba.addTo(map_74dc110f6b9d19a8ba146488bbf047a9);
#
#
#             var marker_7878735c15f6b6fc82ec67085bf3b3a7 = L.marker(
#                 [54.3424974, 10.0997244],
#                 {}
#             ).addTo(map_74dc110f6b9d19a8ba146488bbf047a9);
#
#
#             var icon_2f877c54a5b29dc8230dee01dc456c9a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7878735c15f6b6fc82ec67085bf3b3a7.setIcon(icon_2f877c54a5b29dc8230dee01dc456c9a);
#
#
#         var popup_806120bdb267d435282f4f2db57bb562 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ddc30ec7da272e47f976d8578d55fb69 = $(`&lt;div id=&quot;html_ddc30ec7da272e47f976d8578d55fb69&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Musikschule Kronshagen&lt;/b&gt;&lt;br&gt;&lt;br&gt;&lt;i&gt;amenity:&lt;/i&gt;: music_school&lt;/div&gt;`)[0];
#                 popup_806120bdb267d435282f4f2db57bb562.setContent(html_ddc30ec7da272e47f976d8578d55fb69);
#
#
#
#         marker_7878735c15f6b6fc82ec67085bf3b3a7.bindPopup(popup_806120bdb267d435282f4f2db57bb562)
#         ;
#
#
#
#
#             marker_7878735c15f6b6fc82ec67085bf3b3a7.bindTooltip(
#                 `&lt;div&gt;
#                      Musikschule Kronshagen
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8452b803c8de6c5f50347d8db7a72449 = L.marker(
#                 [54.3080334, 10.1467466],
#                 {}
#             ).addTo(map_74dc110f6b9d19a8ba146488bbf047a9);
#
#
#             var icon_fbf2ee4c0bfaefa2a32535dded0ad0ac = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8452b803c8de6c5f50347d8db7a72449.setIcon(icon_fbf2ee4c0bfaefa2a32535dded0ad0ac);
#
#
#         var popup_181df9db357fad4873dc531d87ab7060 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_602a952ac0f49192680256ff6675268a = $(`&lt;div id=&quot;html_602a952ac0f49192680256ff6675268a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Asia Quick&lt;/b&gt;&lt;br&gt;&lt;br&gt;&lt;i&gt;amenity:&lt;/i&gt;: restaurant&lt;/div&gt;`)[0];
#                 popup_181df9db357fad4873dc531d87ab7060.setContent(html_602a952ac0f49192680256ff6675268a);
#
#
#
#         marker_8452b803c8de6c5f50347d8db7a72449.bindPopup(popup_181df9db357fad4873dc531d87ab7060)
#         ;
#
#
#
#
#             marker_8452b803c8de6c5f50347d8db7a72449.bindTooltip(
#                 `&lt;div&gt;
#                      Asia Quick
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2b5b67bd8fcef918a39a1136d38e0821 = L.marker(
#                 [54.3340585, 10.1365105],
#                 {}
#             ).addTo(map_74dc110f6b9d19a8ba146488bbf047a9);
#
#
#             var icon_e2d92f9015721aef9c4b0ae0bf83bea9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2b5b67bd8fcef918a39a1136d38e0821.setIcon(icon_e2d92f9015721aef9c4b0ae0bf83bea9);
#
#
#         var popup_b24a395d1cbf5a8aacd2678a90d48243 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7f4f86667f0fcd4e2837787684738f08 = $(`&lt;div id=&quot;html_7f4f86667f0fcd4e2837787684738f08&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;YP Studio&lt;/b&gt;&lt;br&gt;&lt;br&gt;&lt;i&gt;amenity:&lt;/i&gt;: music

# %% [markdown]
# check time for hairdressers

# %%
click_point = (54.323334, 10.139444)
radius = 15
i = {"what":["friseur","hair","hairdresser"],"time":"today"} #or today, monday, mo, 03.12.2024

om = OutputManager()
om.perform_search(query=i,point=click_point,area="polygon")
print(len(om.data))
#om.nice_data
om.map
# Out:
# 20
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_28a6373d5b4b5b2d1147541a685b15a9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_28a6373d5b4b5b2d1147541a685b15a9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_28a6373d5b4b5b2d1147541a685b15a9 = L.map(
#                 &quot;map_28a6373d5b4b5b2d1147541a685b15a9&quot;,
#                 {
#                     center: [54.323334, 10.139444],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_76e74e8846526c5e132d3fedfdd6a6a3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_76e74e8846526c5e132d3fedfdd6a6a3.addTo(map_28a6373d5b4b5b2d1147541a685b15a9);
#
#
#         function geo_json_a3341048ef27486fdd9fc732a7440340_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillColor&quot;: &quot;lightgray&quot;};
#             }
#         }
#
#         function geo_json_a3341048ef27486fdd9fc732a7440340_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_
278], [9.1527055, 54.3367362], [9.1526396, 54.3344475], [9.1429651, 54.3302749], [9.1451309, 54.3215089], [9.1472556, 54.3197271], [9.1625352, 54.3173274], [9.1728025, 54.3176214], [9.1619561, 54.3270623], [9.1683081, 54.3321858], [9.1741631, 54.3343676], [9.1814878, 54.3346368], [9.1959567, 54.331507], [9.1968746, 54.3289662], [9.1923823, 54.3232789], [9.1900898, 54.3169496], [9.1924174, 54.3155687], [9.2003531, 54.3214891], [9.2110743, 54.3262576], [9.2149037, 54.3262996], [9.2255011, 54.3225151], [9.2273427, 54.3259637], [9.2271767, 54.33235], [9.2298852, 54.3383583], [9.2

# %% [markdown]
# does the all flag work?
# - yes, but now very slowly!
# - why? because duplicate check is done before search results are filtered i think. for all others this seems to work better, but ofc for all this slows it down!

# %%
"""click_point = (53.67620, 9.66230)
radius = 1
i = {"all":True}

om = OutputManager()
om.perform_search(query=i,point=click_point,area=radius)
print(f"we found {len(om.data)} matches for your query!") #but they are double still
#om.map"""
# Out:
# 'click_point = (53.67620, 9.66230)\nradius = 1\ni = {"all":True}\n\nom = OutputManager()\nom.perform_search(query=i,point=click_point,area=radius)\nprint(f"we found {len(om.data)} matches for your query!") #but they are double still\n#om.map'

# %% [markdown]
# just filter no click, does it work?

# %%
i = {"what":["ferry", "fähre"],"time":"today"} #fähre adds like 10 search results

om = OutputManager()
om.perform_search(query=i)
print(f"we found {len(om.data)} matches for your query!") #but they are double still
#om.nice_data
#om.map
# Out:
# we found 144 matches for your query!

# %% [markdown]
# so look for bestattungen with parking. in one region / in one radius circle!
# - and no event? just look for event true and then consider yourself?

# %%
click_point = (54.323334, 10.139444)
radius = 1
i = {"what":["bestattung","bestattungen","undertaker","parkplatz","parking","parken","fussball"]} #"event"=True

om = OutputManager()
om.perform_search(query=i,point=click_point,area=radius)
print(f"we found {len(om.data)} matches for your query!") #but they are double still
#om.nice_data
#om.map
# Out:
# we found 29 matches for your query!

# %% [markdown]
# just get like something of everything around kiel

# %%
click_point = (54.323334, 10.139444)
radius = 20
i = {"what":["nature","parking"]} 

om = OutputManager()
om.perform_search(query=i,point=click_point,area=radius)
print(f"we found {len(om.data)} matches for your query!") #but they are double still
#om.nice_data
om.map
# Out:
# we found 287 matches for your query!
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6c160604b3e3efa0c72d218a4d22850d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6c160604b3e3efa0c72d218a4d22850d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6c160604b3e3efa0c72d218a4d22850d = L.map(
#                 &quot;map_6c160604b3e3efa0c72d218a4d22850d&quot;,
#                 {
#                     center: [54.323334, 10.139444],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9f50ce4210fedf45893ed3a99cdcd480 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9f50ce4210fedf45893ed3a99cdcd480.addTo(map_6c160604b3e3efa0c72d218a4d22850d);
#
#
#             var marker_9875d6453da2f862ad0444a36edc4b5b = L.marker(
#                 [54.3219241, 10.1673873],
#                 {}
#             ).addTo(map_6c160604b3e3efa0c72d218a4d22850d);
#
#
#             var icon_5d06331917e5cdbbc097541365f26c4e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9875d6453da2f862ad0444a36edc4b5b.setIcon(icon_5d06331917e5cdbbc097541365f26c4e);
#
#
#         var popup_57e5d657ad8e42f4b647ffede78b7d69 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d7ac23a185413d608bd284221e6a88e1 = $(`&lt;div id=&quot;html_d7ac23a185413d608bd284221e6a88e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;None&lt;/b&gt;&lt;br&gt;&lt;br&gt;&lt;i&gt;amenity:&lt;/i&gt;: parking&lt;/div&gt;`)[0];
#                 popup_57e5d657ad8e42f4b647ffede78b7d69.setContent(html_d7ac23a185413d608bd284221e6a88e1);
#
#
#
#         marker_9875d6453da2f862ad0444a36edc4b5b.bindPopup(popup_57e5d657ad8e42f4b647ffede78b7d69)
#         ;
#
#
#
#
#             var marker_5a501bd432a456e454a9c24e985edf0c = L.marker(
#                 [54.3269812, 10.1391411],
#                 {}
#             ).addTo(map_6c160604b3e3efa0c72d218a4d22850d);
#
#
#             var icon_3ee9da86eb93309650004ab7fea9a3dd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5a501bd432a456e454a9c24e985edf0c.setIcon(icon_3ee9da86eb93309650004ab7fea9a3dd);
#
#
#         var popup_e8f793d3800372024f2e2cfec177054d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_930a5eb641d1e633a5886ae0bcd9f745 = $(`&lt;div id=&quot;html_930a5eb641d1e633a5886ae0bcd9f745&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;None&lt;/b&gt;&lt;br&gt;&lt;br&gt;&lt;i&gt;amenity:&lt;/i&gt;: parking_entrance&lt;/div&gt;`)[0];
#                 popup_e8f793d3800372024f2e2cfec177054d.setContent(html_930a5eb641d1e633a5886ae0bcd9f745);
#
#
#
#         marker_5a501bd432a456e454a9c24e985edf0c.bindPopup(popup_e8f793d3800372024f2e2cfec177054d)
#         ;
#
#
#
#
#             var marker_2eda38136f428c0fc298b5bc5995a394 = L.marker(
#                 [54.3265426, 10.1422584],
#                 {}
#             ).addTo(map_6c160604b3e3efa0c72d218a4d22850d);
#
#
#             var icon_e0354116894d492a482ed94e38a1273b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2eda38136f428c0fc298b5bc5995a394.setIcon(icon_e0354116894d492a482ed94e38a1273b);
#
#
#         var popup_1c3f36dd98d135e226da05987f5bde75 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5bb5e2dccd28c8b93178a45ec444142b = $(`&lt;div id=&quot;html_5bb5e2dccd28c8b93178a45ec444142b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Hotel Steigenberger Conti Hansa&lt;/b&gt;&lt;br&gt;&lt;br&gt;&lt;i&gt;amenity:&lt;/i&gt;: parking&lt;/div&gt;`)[0];
#                 popup_1c3f36dd98d135e226da05987f5bde75.setContent(html_5bb5e2dccd28c8b93178a45ec444142b);
#
#
#
#         marker_2eda38136f428c0fc298b5bc5995a394.bindPopup(popup_1c3f36dd98d135e226da05987f5bde75)
#         ;
#
#
#
#
#             marker_2eda38136f428c0fc298b5bc5995a394.bindTooltip(
#                 `&lt;div&gt;
#                      Hotel Steigenberger Conti Hansa
#                  &lt;/div&gt;`,

# %% [markdown]
# now get something of everything around plön? (no events and no nature cause no data for this location)

# %%
click_point = (54.20840, 10.41490) #plön
i = {"what":["segeln","sailing","wassersport","burger"]} 

om = OutputManager()
om.perform_search(query=i,point=click_point,area="polygon")
print(f"we found {len(om.data)} matches for your query!") #but they are double still
#om.nice_data
#om.map
# Out:
# we found 5 matches for your query!

# %% [markdown]
# ---

# %% [markdown]
# # 5 experiments nlp

# %% [markdown]
# ### now try nlp search

# %%
query = "Ich will mir morgen die haare schneiden lassen welche friseure haben auf"
om.nlp_search(nlp=query)
print(f"we found {len(om.data)} matches for your query!")
#om.nice_data
om.map
# Out:
# we found 16 matches for your query!
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_99ee04f6450ca6050c8ae40c57d912b0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_99ee04f6450ca6050c8ae40c57d912b0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_99ee04f6450ca6050c8ae40c57d912b0 = L.map(
#                 &quot;map_99ee04f6450ca6050c8ae40c57d912b0&quot;,
#                 {
#                     center: [54.2194, 9.6961],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1653f854949ca415f53ae5e0f7ff969d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1653f854949ca415f53ae5e0f7ff969d.addTo(map_99ee04f6450ca6050c8ae40c57d912b0);
#
#
#             var marker_909f165eb1f376d884a1a215659f86ce = L.marker(
#                 [54.28159, 10.2037735],
#                 {}
#             ).addTo(map_99ee04f6450ca6050c8ae40c57d912b0);
#
#
#             var icon_eed2b10783f604dab670fd745477862b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_909f165eb1f376d884a1a215659f86ce.setIcon(icon_eed2b10783f604dab670fd745477862b);
#
#
#         var popup_6517973a311309e543cfb41f010e035f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0d5904287183219d7f60c6851628fe09 = $(`&lt;div id=&quot;html_0d5904287183219d7f60c6851628fe09&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Marn und Marn Hausverwaltung&lt;/b&gt;&lt;br&gt;&lt;br&gt;&lt;i&gt;link:&lt;/i&gt;: &lt;a href=&#x27;nan&#x27;&gt;nan&lt;/a&gt;&lt;br&gt;&lt;i&gt;tel.:&lt;/i&gt; 0431 7 89 08 66&lt;br&gt;&lt;i&gt;address:&lt;/i&gt; Plötzen 10, 24146, Kiel&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_6517973a311309e543cfb41f010e035f.setContent(html_0d5904287183219d7f60c6851628fe09);
#
#
#
#         marker_909f165eb1f376d884a1a215659f86ce.bindPopup(popup_6517973a311309e543cfb41f010e035f)
#         ;
#
#
#
#
#             marker_909f165eb1f376d884a1a215659f86ce.bindTooltip(
#                 `&lt;div&gt;
#                      Marn und Marn Hausverwaltung
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_bbeca6e6ac16fe635d1057e680d43d2e = L.marker(
#                 [54.33898, 10.134721],
#                 {}
#             ).addTo(map_99ee04f6450ca6050c8ae40c57d912b0);
#
#
#             var icon_676efe30c06ff5e576f8ae2f9bb1d803 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bbeca6e6ac16fe635d1057e680d43d2e.setIcon(icon_676efe30c06ff5e576f8ae2f9bb1d803);
#
#
#         var popup_ba5903d7ae8f21aa7858a7cc6882785c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cde87ca8d0d86a535e34ebb5a8a0a0d5 = $(`&lt;div id=&quot;html_cde87ca8d0d86a535e34ebb5a8a0a0d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Hausverwaltung Marn u. Marn&lt;/b&gt;&lt;br&gt;&lt;br&gt;&lt;i&gt;link:&lt;/i&gt;: &lt;a href=&#x27;nan&#x27;&gt;nan&lt;/a&gt;&lt;br&gt;&lt;i&gt;tel.:&lt;/i&gt; 0431 8 00 86 15&lt;br&gt;&lt;i&gt;address:&lt;/i&gt; Wrangelstr. 59, 24105, Kiel&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_ba5903d7ae8f21aa7858a7cc6882785c.setContent(html_cde87ca8d0d86a535e34ebb5a8a0a0d5);
#
#
#
#         marker_bbeca6e6ac16fe635d1057e680d43d2e.bindPopup(popup_ba5903d7ae8f21aa7858a7cc6882785c)
#         ;
#
#
#
#
#             marker_bbeca6e6ac16fe635d1057e680d43d2e.bindTooltip(
#                 `&lt;div&gt;
#                      Hausverwaltung Marn u. Marn
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6b426d8567cbade9ca0df306d83d0bed = L.marker(
#                 [54.372135, 10.20692],
#                 {}
#             ).addTo(map_99ee04f6450ca6050c8ae40c57d912b0);
#
#
#             var icon_0b529d32680b9cd8db7cd7572a974da2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6b426d8567cbade9ca0df306d83d0bed.setIcon(icon_0b529d32680b9cd8db7cd7572a974da2);
#
#
#         var popup_fc0e85eb20661b7a2062f6b6da1

# %%
query = "i am looking for parking spaces"

om = OutputManager()
om.nlp_search(nlp=query)
print(f"we found {len(om.data)} matches for your query!") #but they are double still
#om.nice_data
om.map
# Out:
# we found 20 matches for your query!
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_15cfe62b1db3cdb6a336d32ef223cc4b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_15cfe62b1db3cdb6a336d32ef223cc4b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_15cfe62b1db3cdb6a336d32ef223cc4b = L.map(
#                 &quot;map_15cfe62b1db3cdb6a336d32ef223cc4b&quot;,
#                 {
#                     center: [54.2194, 9.6961],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_999d45d9847c793f669db4696c5f3e83 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_999d45d9847c793f669db4696c5f3e83.addTo(map_15cfe62b1db3cdb6a336d32ef223cc4b);
#
#
#             var marker_a63ce98a780f133bd18d34b4f6e7b732 = L.marker(
#                 [54.3134988, 10.1470278],
#                 {}
#             ).addTo(map_15cfe62b1db3cdb6a336d32ef223cc4b);
#
#
#             var icon_300b93aa1699f1a15f703d409169d0e4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a63ce98a780f133bd18d34b4f6e7b732.setIcon(icon_300b93aa1699f1a15f703d409169d0e4);
#
#
#         var popup_f21e9839bd696ac4809afcc5dea8bdf8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1b58a95a2716f69cc261baddc77d7a46 = $(`&lt;div id=&quot;html_1b58a95a2716f69cc261baddc77d7a46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;None&lt;/b&gt;&lt;br&gt;&lt;br&gt;&lt;i&gt;amenity:&lt;/i&gt;: bicycle_parking&lt;/div&gt;`)[0];
#                 popup_f21e9839bd696ac4809afcc5dea8bdf8.setContent(html_1b58a95a2716f69cc261baddc77d7a46);
#
#
#
#         marker_a63ce98a780f133bd18d34b4f6e7b732.bindPopup(popup_f21e9839bd696ac4809afcc5dea8bdf8)
#         ;
#
#
#
#
#             var marker_8ee4d2fd07938b73c3d0b99609fda309 = L.marker(
#                 [54.3423754, 10.1323956],
#                 {}
#             ).addTo(map_15cfe62b1db3cdb6a336d32ef223cc4b);
#
#
#             var icon_37adbf6badf63edc343333c053106518 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8ee4d2fd07938b73c3d0b99609fda309.setIcon(icon_37adbf6badf63edc343333c053106518);
#
#
#         var popup_9e51848f7f970aef81c314e1a1f9bdc0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aecdd4653a7e480de0897ed4842351f7 = $(`&lt;div id=&quot;html_aecdd4653a7e480de0897ed4842351f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;None&lt;/b&gt;&lt;br&gt;&lt;br&gt;&lt;i&gt;amenity:&lt;/i&gt;: bicycle_parking&lt;/div&gt;`)[0];
#                 popup_9e51848f7f970aef81c314e1a1f9bdc0.setContent(html_aecdd4653a7e480de0897ed4842351f7);
#
#
#
#         marker_8ee4d2fd07938b73c3d0b99609fda309.bindPopup(popup_9e51848f7f970aef81c314e1a1f9bdc0)
#         ;
#
#
#
#
#             var marker_1b2b124df7790bfe0e8fad654d4990f2 = L.marker(
#                 [54.2284627, 10.187683],
#                 {}
#             ).addTo(map_15cfe62b1db3cdb6a336d32ef223cc4b);
#
#
#             var icon_eead7a2276937ccdc16025a109ed9206 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1b2b124df7790bfe0e8fad654d4990f2.setIcon(icon_eead7a2276937ccdc16025a109ed9206);
#
#
#         var popup_51e1e00d40f55589c3abc9d8c2e373d7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_54cc1a2207e97bd211357e2c3e08877a = $(`&lt;div id=&quot;html_54cc1a2207e97bd211357e2c3e08877a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;None&lt;/b&gt;&lt;br&gt;&lt;br&gt;&lt;i&gt;amenity:&lt;/i&gt;: bicycle_parking&lt;/div&gt;`)[0];
#                 popup_51e1e00d40f55589c3abc9d8c2e373d7.setContent(html_54cc1a2207e97bd211357e2c3e08877a);
#
#
#
#         marker_1b2b124df7790bfe0e8fad654d4990f2.bindPopup(popup_51e1e00d40f55589c3abc9d8c2e373d7)
#         ;
#
#
#
#
#             var marker_64c066215211614c13f125f5814639f7 = L.marker(
#                 [54.1282856, 8.8696468],
#                 {}
#             ).addTo(map_15cfe62b1db3cdb6a336d32ef223cc4b);

# %%
query = "ich will blumen kaufen und öffentliche verkehrmittel benutzen entweder bus oder fähre"

om = OutputManager()
om.nlp_search(nlp=query)
print(f"we found {len(om.data)} matches for your query!")
#om.nice_data
om.map
# Out:
# we found 7 matches for your query!
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e6c923b47dea6d69c263bc7702651b4b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e6c923b47dea6d69c263bc7702651b4b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e6c923b47dea6d69c263bc7702651b4b = L.map(
#                 &quot;map_e6c923b47dea6d69c263bc7702651b4b&quot;,
#                 {
#                     center: [54.2194, 9.6961],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f0a5e2e682eb18fd6e9a5daf8f110568 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f0a5e2e682eb18fd6e9a5daf8f110568.addTo(map_e6c923b47dea6d69c263bc7702651b4b);
#
#
#             var marker_7c066495c70745dca956cc657ad62051 = L.marker(
#                 [54.319122, 10.098283],
#                 {}
#             ).addTo(map_e6c923b47dea6d69c263bc7702651b4b);
#
#
#             var icon_346247d2111a4113f6ad12d35ed9bb4c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7c066495c70745dca956cc657ad62051.setIcon(icon_346247d2111a4113f6ad12d35ed9bb4c);
#
#
#         var popup_0cbdaa219da65f0c9936bef819b5d0b7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1123147d87cb3008f61ef94cbf309698 = $(`&lt;div id=&quot;html_1123147d87cb3008f61ef94cbf309698&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Der Kieler Jung&lt;/b&gt;&lt;br&gt;&lt;br&gt;&lt;i&gt;link:&lt;/i&gt;: &lt;a href=&#x27;http://www.derkielerjung.de&#x27;&gt;http://www.derkielerjung.de&lt;/a&gt;&lt;br&gt;&lt;i&gt;tel.:&lt;/i&gt; 0431 8 89 95 98&lt;br&gt;&lt;i&gt;address:&lt;/i&gt; Hasseldieksdammer Weg 179, 24114, Kiel&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_0cbdaa219da65f0c9936bef819b5d0b7.setContent(html_1123147d87cb3008f61ef94cbf309698);
#
#
#
#         marker_7c066495c70745dca956cc657ad62051.bindPopup(popup_0cbdaa219da65f0c9936bef819b5d0b7)
#         ;
#
#
#
#
#             marker_7c066495c70745dca956cc657ad62051.bindTooltip(
#                 `&lt;div&gt;
#                      Der Kieler Jung
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6fdc5ad050c6f392a268357928b5526d = L.marker(
#                 [54.32664, 10.116633],
#                 {}
#             ).addTo(map_e6c923b47dea6d69c263bc7702651b4b);
#
#
#             var icon_77c159310f38889f9e1e8a28ca174ad6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6fdc5ad050c6f392a268357928b5526d.setIcon(icon_77c159310f38889f9e1e8a28ca174ad6);
#
#
#         var popup_64cd7ea766e17f9d577ae2df748278f2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_887787dae16e910aaabc82a229667bf7 = $(`&lt;div id=&quot;html_887787dae16e910aaabc82a229667bf7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Debeka Servicebüro Kiel Weißenburgstr. (Versicherungen und Bausparen)&lt;/b&gt;&lt;br&gt;&lt;br&gt;&lt;i&gt;link:&lt;/i&gt;: &lt;a href=&#x27;https://www.debeka.de/svb/kiel6&#x27;&gt;https://www.debeka.de/svb/kiel6&lt;/a&gt;&lt;br&gt;&lt;i&gt;tel.:&lt;/i&gt; 0431 12 85 44 88&lt;br&gt;&lt;i&gt;address:&lt;/i&gt; Weißenburgstr. 50, 24116, Kiel&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_64cd7ea766e17f9d577ae2df748278f2.setContent(html_887787dae16e910aaabc82a229667bf7);
#
#
#
#         marker_6fdc5ad050c6f392a268357928b5526d.bindPopup(popup_64cd7ea766e17f9d577ae2df748278f2)
#         ;
#
#
#
#
#             marker_6fdc5ad050c6f392a268357928b5526d.bindTooltip(
#                 `&lt;div&gt;
#                      Debeka Servicebüro Kiel Weißenburgstr. (Versicherungen und Bausparen)
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_776f8c6d799cbcc4bd3e4fb4e03622d7 = L.marker(
#                 [54.363712, 10.202581],
#                 {}
#             ).addTo(map_e6c923b47dea6d69c263bc7702651b4b);
#
#
#             var icon_ec7d923603a7931e9cbf917c7885da2d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon

# %%
query = "gibt es advents oder weihnachts events"

om = OutputManager()
om.nlp_search(nlp=query)
print(f"we found {len(om.data)} matches for your query!")
#om.nice_data
#om.map
# Out:
# we found 3 matches for your query!

# %%
query = "ich suche events oder aktivitäten mit musik also zb live musik oder karaoke; und ich suche parking spaces in der nähe"

om = OutputManager()
om.nlp_search(nlp=query)
print(f"we found {len(om.data)} matches for your query!")
#om.nice_data
om.map
# Out:
# we found 14 matches for your query!
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_786d2902625eb1f51dcd47a0f5c200b4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_786d2902625eb1f51dcd47a0f5c200b4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_786d2902625eb1f51dcd47a0f5c200b4 = L.map(
#                 &quot;map_786d2902625eb1f51dcd47a0f5c200b4&quot;,
#                 {
#                     center: [54.2194, 9.6961],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9b88ce6b48190ac837651063ea1b7142 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9b88ce6b48190ac837651063ea1b7142.addTo(map_786d2902625eb1f51dcd47a0f5c200b4);
#
#
#             var marker_c2ec51a5f102837c06549ca43d621eab = L.marker(
#                 [53.8645197, 10.6815066],
#                 {}
#             ).addTo(map_786d2902625eb1f51dcd47a0f5c200b4);
#
#
#             var icon_d4ee825e03cbabce8733c896c282c9e2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c2ec51a5f102837c06549ca43d621eab.setIcon(icon_d4ee825e03cbabce8733c896c282c9e2);
#
#
#         var popup_3f4032c23d0f501fa1906bc25e064735 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6b97414595f074037bf14d51bc1583ca = $(`&lt;div id=&quot;html_6b97414595f074037bf14d51bc1583ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Großer Saal Musikhochschule Lübeck&lt;/b&gt;&lt;br&gt;&lt;br&gt;&lt;i&gt;amenity:&lt;/i&gt;: theatre&lt;/div&gt;`)[0];
#                 popup_3f4032c23d0f501fa1906bc25e064735.setContent(html_6b97414595f074037bf14d51bc1583ca);
#
#
#
#         marker_c2ec51a5f102837c06549ca43d621eab.bindPopup(popup_3f4032c23d0f501fa1906bc25e064735)
#         ;
#
#
#
#
#             marker_c2ec51a5f102837c06549ca43d621eab.bindTooltip(
#                 `&lt;div&gt;
#                      Großer Saal Musikhochschule Lübeck
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3a512927b0f1cfc157fdff779676e470 = L.marker(
#                 [53.8376158, 9.9638553],
#                 {}
#             ).addTo(map_786d2902625eb1f51dcd47a0f5c200b4);
#
#
#             var icon_935240d531b307adcf1c670429f06398 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3a512927b0f1cfc157fdff779676e470.setIcon(icon_935240d531b307adcf1c670429f06398);
#
#
#         var popup_448ce2ec52e5c7f9c1c029784e5e5c41 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_25aded9e922c2473dea552c1a9a40f1e = $(`&lt;div id=&quot;html_25aded9e922c2473dea552c1a9a40f1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Musikschule KSK&lt;/b&gt;&lt;br&gt;&lt;br&gt;&lt;i&gt;amenity:&lt;/i&gt;: school&lt;/div&gt;`)[0];
#                 popup_448ce2ec52e5c7f9c1c029784e5e5c41.setContent(html_25aded9e922c2473dea552c1a9a40f1e);
#
#
#
#         marker_3a512927b0f1cfc157fdff779676e470.bindPopup(popup_448ce2ec52e5c7f9c1c029784e5e5c41)
#         ;
#
#
#
#
#             marker_3a512927b0f1cfc157fdff779676e470.bindTooltip(
#                 `&lt;div&gt;
#                      Musikschule KSK
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8960e063ef89ed47ab7e3c6b9a53844b = L.marker(
#                 [53.8702024, 10.6790636],
#                 {}
#             ).addTo(map_786d2902625eb1f51dcd47a0f5c200b4);
#
#
#             var icon_7ee088ce1f1426f8e4558615b7dda699 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;gray&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8960e063ef89ed47ab7e3c6b9a53844b.setIcon(icon_7ee088ce1f1426f8e4558615b7dda699);
#
#
#         var popup_f2063e374bc030bc402e9c39bb6d4009 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6f415e9245740f16193d395e17dd9ba1 = $(`&lt;div id=&quot;html_6f415e9245740f16193d395e17dd9ba1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Musik und Kongesshalle (MUK) / Busparkplatz&lt;/b&gt;&
