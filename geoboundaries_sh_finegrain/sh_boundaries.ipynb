# %%
# Starter code
import numpy as np
import osmnx as ox
import geopandas as gpd
import pandas as pd
import folium

# %%
# Geo Data from Open Street Map
tags = {'admin_level': '6'}
geo = ox.features_from_place(
    query="Schleswig-Holstein, Germany",
    tags=tags)
geo = geo.reset_index()
geo = geo[geo.element_type=='relation']
geo.head(3)
# Out:
# c:\Users\dorar\Documents\kiel\data_science\semester_2\application_projects\dataLab_kiel\code\SH_data_platform\datalab_venv\Lib\site-packages\osmnx\_overpass.py:254: UserWarning: This area is 12 times your configured Overpass max query area size. It will automatically be divided up into multiple sub-queries accordingly. This may take a long time.
#   multi_poly_proj = utils_geo._consolidate_subdivide_geometry(poly_proj)
#     element_type  osmid                                           geometry  \
# 171     relation  27027  MULTIPOLYGON (((10.64059 53.78700, 10.64047 53...
# 172     relation  62546  MULTIPOLYGON (((10.11538 53.71466, 10.11550 53...
# 173     relation  62703  POLYGON ((10.23831 53.49620, 10.23881 53.49657...
#
#                     name name:ar name:cs name:da name:de name:el name:en  ...  \
# 171               Lübeck    لوبك   Lubek   Lybæk  Lübeck  Λίμπεκ  Lübeck  ...
# 172             Stormarn     NaN     NaN     NaN     NaN     NaN     NaN  ...
# ...

# %%
geo.to_csv("sh_boundaries_6.csv")
