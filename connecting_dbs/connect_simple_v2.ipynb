# %%
import numpy as np
import pandas as pd

from datetime import datetime

import geopandas as gpd
from geopy.distance import geodesic
import geopy

import osmnx as ox
import networkx as nx
import folium

from pymongo import MongoClient

from bs4 import BeautifulSoup
import requests

from selenium import webdriver ## Driver for Firefox, Chrome, Edge, etc.
from selenium.webdriver.common.by import By # Mode of locating html elements: ID, CSS_SELECTOR, XPATH, ...
from selenium.webdriver.support.select import Select

import spacy
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# ## Mongo set up as always

# %%
def set_up_mongo(client_str,database_str,collection_str):
    client = MongoClient(client_str) #connect to mongodb client
    db = client[database_str] #connect to database

    existing_collections = db.list_collection_names() #check that dbs collections
    if collection_str not in existing_collections:
        db.create_collection(collection_str) #create collection if needed
    
    my_collection = db[collection_str] #connect to collection

    return my_collection

# %% [markdown]
# two collections for the data

# %%
coll_yp = set_up_mongo('mongodb://localhost:27017','webscraping_dataLabKiel','yellow_pages') 
coll_osm = set_up_mongo('mongodb://localhost:27017','webscraping_dataLabKiel','osm_pois')

# %% [markdown]
# ### helper functions

# %% [markdown]
# helper function yp unique business since many duplicates

# %%
def unique_business(b):
    unique_buis = []
    new_b = [x for x in b if "@id" in x.keys()]  #only those items which have primary key
    links = [x["@id"] for x in new_b] 
    links = list(set(links)) #make this list unique
    for e in new_b: 
        if e["@id"] in links:
            links.remove(e["@id"])
            unique_buis.append(e)
    return unique_buis

# %% [markdown]
# since for osm data its lat, lon and for yp data latitude ..., its easier for plotting function to change it (and also sort out stuff that doesnt have this)

# %%
def change_to_LATLON(b):
    lat_lons = []
    for e in b:
        new_dict = {('lat' if k == 'latitude' else 'lon' if k == 'longitude' else k): v for k, v in e.items()} #change naming to be the same for plotting
        if "lat" in new_dict.keys() and "lon" in new_dict.keys():
            lat_lons.append(new_dict)
    return lat_lons

# %% [markdown]
# ### previous plotting function

# %%
def popupStr_generator(df_row):
    pps = f"<b>{df_row["name"]}</b>"
    features = df_row.index
    values = df_row.values
    for f,v in zip(features,values):
        if f in ["telephone","amenity","sameAs"]:
            pps += f"<br>{f}: {v}"
        else:
            pps += ""
    return pps

# %%
def plot_spots(data,z):
    poi_df = pd.DataFrame(data) #compile business sample into df
    poi_df["lat"] = pd.to_numeric(poi_df["lat"])
    poi_df["lon"] = pd.to_numeric(poi_df["lon"])
    map_center = [poi_df['lat'].mean(), poi_df['lon'].mean()] # Center the map around the mean latitude and longitude of the POIs
    m = folium.Map(location=map_center, zoom_start=z, tiles='OpenStreetMap') # Initialize the folium map with OpenStreetMap tiles

    # Add markers with popups for each POI
    for _, row in poi_df.iterrows():
        folium.Marker(
            location=[row['lat'], row['lon']],
            popup=popupStr_generator(row),
            tooltip=row['name']
        ).add_to(m)
    
    return m

# %% [markdown]
# ## Queries

# %% [markdown]
# set up a function where i can pass a dictionary of key words, and it retrieves data from the databses as needed

# %%
query_format = {"where":_, #location e.g. Lübeck, Arkebek, Flensburg etc
                "what_general":_, #type of amnenity (only retrieves osm) e.g. pub, restaurant, parking etc
                "what_specific":_, #like pizza, italian, ... (searches the names)
                "special_tag":_} #like specific types of service e.g. reparatur, putzen, etc...

#but order doesnt matter

# %% [markdown]
# this function gets a dictionary like above, and then according to the combination of keys passed retrieves data. the query logic differs depending on key words, so have differing underlying logic in setting up query dict.
#
# for example:
# - kebab places in lübeck -> 'and' connection (only retrieves yp data since rn only thats with place location, otherwise need geofencing)
# - reparatur (passed both what_specific and special_tag -> search for occurence of reparatur both in names of yp and osm data + special tags of yp data)

# %%
def create_more_complex_search_string(q,which_db):
    query_dict = {}
    if which_db == "osm":
        if "where" in q.keys():
            #technically this should be some geolocation magic, but as it isnt yet ask for sth impossible
            query_dict.update({"id": "thisisanimprobableid"})
        else: 
            if ("what_general" in q.keys()) and ("what_specific" in q.keys()):
                query_dict.update({"$or": [{"amenity": { "$regex": f"{q["what_general"]}", "$options": "i" }},{"name": { "$regex": f"{q["what_specific"]}", "$options": "i" }}]})   
            elif "what_general" in q.keys():
                query_dict.update({"amenity": { "$regex": f"{q["what_general"]}", "$options": "i" }})
            elif "what_specific" in q.keys():
                query_dict.update({"name": { "$regex": f"{q["what_specific"]}", "$options": "i" }})

    #basically, go from most complex through least complex: first try 3, then all 2 combinations, and then 1s
    if which_db == "yp":
        if ("where" in q.keys()) and ("what_specific" in q.keys()) and ("special_tag" in q.keys()):
            query_dict.update({"$and": [{"address.addressLocality":f"{q["where"]}"}, 
                                        {"$or": [{"name": { "$regex": f"{q["what_specific"]}", "$options": "i" }},{"keywords": { "$regex": f"{q["special_tag"]}", "$options": "i" }}]}]})
        elif ("where" in q.keys()) and ("what_specific" in q.keys()):
            query_dict.update({"$and": [{"address.addressLocality":f"{q["where"]}"}, {"name": { "$regex": f"{q["what_specific"]}", "$options": "i" }}]})
        elif ("where" in q.keys()) and ("special_tag" in q.keys()):
            query_dict.update({"$and": [{"address.addressLocality":f"{q["where"]}"}, {"keywords": { "$regex": f"{q["special_tag"]}", "$options": "i" }}]})
        elif ("special_tag" in q.keys()) and ("what_specific" in q.keys()):
            query_dict.update({"$or": [{"keywords": { "$regex": f"{q["special_tag"]}", "$options": "i" }}, {"name": { "$regex": f"{q["what_specific"]}", "$options": "i" }}]})
        elif ("special_tag" in q.keys()):
            query_dict.update({"keywords": { "$regex": f"{q["special_tag"]}", "$options": "i" }})
        elif ("what_specific" in q.keys()):
            query_dict.update({"name": { "$regex": f"{q["what_specific"]}", "$options": "i" }})
        elif ("where" in q.keys()):
            query_dict.update({"address.addressLocality":f"{q["where"]}"})

    return query_dict

# %% [markdown]
# this is just getting both the collection and the already made query dict and retrieves data accordingly

# %% [markdown]
# #### try normal input text to query dict funtion
#
# **could also try doing this with an llm** but for now try:
# - check if a word is in the list of all cities -> where (in theory, could also add landkreise, but then where key word would also need to be refined)
# - get list of possible amenity tags -> check if word is in there
# - any adj / adv description -> what_specific and special_tag
#
# - could have used synonyms for both amenities, as well as name and special tag searches, but at least chatgtp synonym finder function isnt good right now

# %% [markdown]
# ### helper functions: get stacks to look through basically

# %%
#GET ALL CITIES

def county_search():
    #go to start page and make into soup html obj
    url = "https://www.gelbeseiten.de/branchenbuch/staedte/schleswig-holstein/landkreise"
    html = requests.get(url).text
    soup = BeautifulSoup(html, 'html.parser')
    
    #find all counties
    lk = soup.find_all(class_="filterlist__item")
    landkreis_stack = [] #create empty stack to put counties into (not a stack tho)
    for e in lk:
        county_refined = e.text.lower()
        county_refined = county_refined.strip()
        landkreis_stack.append(county_refined)

    return landkreis_stack


# ----- FIND CITIES IN PER COUNTY -----
def city_search(county_in_question):
    #pass relevant counties as argument and get its cities
    url = f"https://www.gelbeseiten.de/branchenbuch/staedte/schleswig-holstein/{county_in_question}"
    #print(url) #remove or comment later
    html = requests.get(url).text
    soup = BeautifulSoup(html, 'html.parser')

    places = soup.find_all(class_="boxteaser__title")

    city_stack = []
    for e in places:
        city_stack.append(e.text.lower()) #append all city names (for one county)

    return city_stack

# %%
# GET ALL AMENITIES
c = set_up_mongo('mongodb://localhost:27017','webscraping_dataLabKiel','osm_pois') #establish connection
available_amenities = [x["amenity"] for x in c.find({},{"_id":0})]
available_amenities = list(set(available_amenities))

# %%
"""#import spacy
#python -m spacy download en_core_web_sm

nlp = spacy.load("en_core_web_sm")
doc = nlp("i am looking for car repair shops")

#would ideally yield car and repais, but not shops (could do with repair shops but thats compound nouns then)

# Print each word with its part of speech tag
tokens = {}
for token in doc:
    tokens.update({token.pos_:token.text})
#[k for v,k in tokens.items() if (v=="ADJ" or v=="NOUN") ] #doesnt find repair because repair is assumed to modify shop 
#yields: ['shops']
tokens"""
# Out:
# '#import spacy\n#python -m spacy download en_core_web_sm\n\nnlp = spacy.load("en_core_web_sm")\ndoc = nlp("i am looking for car repair shops")\n\n#would ideally yield car and repais, but not shops (could do with repair shops but thats compound nouns then)\n\n# Print each word with its part of speech tag\ntokens = {}\nfor token in doc:\n    tokens.update({token.pos_:token.text})\n#[k for v,k in tokens.items() if (v=="ADJ" or v=="NOUN") ] #doesnt find repair because repair is assumed to modify shop \n#yields: [\'shops\']\ntokens'

# %%
input_query = "I am looking for reparatur shops or repair shops"

#look for compound nouns
doc = nlp(input_query)
chunkss = []
for chunk in doc.noun_chunks:
    chunkss.append(chunk.text)

# %%
chunkss
# Out:
# ['I', 'reparatur shops', 'repair shops']

# %%
input_query = "where is a shop where I could fix my car door"
query_sep = input_query.split()
tokens = {}
for t in query_sep:
    doc = nlp(t)
    for token in doc:
        tokens.update({token.text:token.pos_})
my_search = [k for k,v in tokens.items() if v=="NOUN"]

# %%
my_search
# Out:
# ['shop', 'fix', 'car', 'door']

# %%
def make_list_into_noun_terms(list):
    tokens = {}
    for t in list:
        doc = nlp(t)
        for token in doc:
            tokens.update({token.text:token.pos_})
    my_search = [k for k,v in tokens.items() if v=="NOUN"]
    return my_search

# %%
def input_to_query_terms(input):
    
    #look for compound nouns
    doc_1 = nlp(input)
    chunkss = []
    for chunk in doc_1.noun_chunks:
        chunkss.append(chunk.text)

    query_sep = input.split()    
    list_of_options = make_list_into_noun_terms(query_sep) #only search for real nouns but include compound nouns (here we could also get like top 5 synonyms)
    list_of_options = list(set(list_of_options + chunkss))
    list_of_options = [e for e in list_of_options if (e not in ["I","i","you","Your"])] 

    #get rid of pronouns sadly like this
    return list_of_options

# %%
q1 = "I am looking for bike repair shops in Lübeck"
print(input_to_query_terms(q1))
q1 = input_to_query_terms(q1)
# Out:
# ['bike repair shops', 'bike', 'repair', 'Lübeck', 'shops']

# %%
q2 = "where is a shop so i could fix my bike in lübeck"
print(input_to_query_terms(q2))
q2 = input_to_query_terms(q2)
# Out:
# ['bike', 'my bike', 'lübeck', 'a shop', 'fix', 'shop']

# %% [markdown]
# also actually output multiple dicts, similar-ish to search options, to really actually search all the combinations

# %%
def qTerm_to_query_dict(terms):
    #ALL AMENITIES
    c = set_up_mongo('mongodb://localhost:27017','webscraping_dataLabKiel','osm_pois') #establish connection
    available_amenities = [x["amenity"] for x in c.find({},{"_id":0})]
    available_amenities = list(set(available_amenities))

    #ALL CITIES
    all_cities_sh = []
    lk_stack = county_search()
    for lk in lk_stack:
        c = city_search(lk)
        all_cities_sh.extend(c)
    all_cities_sh = all_cities_sh + ["Kiel","Flensburg","Neumünster","Lübeck"] #add kreisfreie städe

    #search_dicts = [] BUT basically do this, only for terms at len -1, -2, -3 to get multiple combinations? but also not really, cause location always
    qd = {}
    for t in terms:
        if t in all_cities_sh:
            qd.update({"where":t})
        if t in available_amenities:
            qd.update({"what_general":t})

        qd.update({"what_specific":t})
        qd.update({"special_tag":t})
    return qd

# %%
qTerm_to_query_dict(q1)
# Out:
# {'what_specific': 'shops', 'special_tag': 'shops', 'where': 'Lübeck'}

# %%
qTerm_to_query_dict(q2) #just picks last term in list, cause only 1 dictionary, disregards lübeck cause lower case in input string
# Out:
# {'what_specific': 'shop', 'special_tag': 'shop'}

# %% [markdown]
# try via synonyms? so more search words findable. but dont use this

# %%
"""from nltk.corpus import wordnet

# Function to get synonyms
def get_synonyms(word):
    synonyms = set()
    for syn in wordnet.synsets(word):
        for lemma in syn.lemmas():
            synonyms.add(lemma.name())
    return list(synonyms)

# Example usage
word = "repair"
synonyms = get_synonyms(word)
print(f"Synonyms for '{word}':", synonyms)

#yeah i dont like these synonyms, not gonna use them"""
# Out:
# 'from nltk.corpus import wordnet\n\n# Function to get synonyms\ndef get_synonyms(word):\n    synonyms = set()\n    for syn in wordnet.synsets(word):\n        for lemma in syn.lemmas():\n            synonyms.add(lemma.name())\n    return list(synonyms)\n\n# Example usage\nword = "repair"\nsynonyms = get_synonyms(word)\nprint(f"Synonyms for \'{word}\':", synonyms)\n\n#yeah i dont like these synonyms, not gonna use them'

# %% [markdown]
# ### retrieve data by passing collection and finished search dict

# %%
def retrieve_data(collection,query_dict): 
    available_buiz = [x for x in collection.find(query_dict,{'_id':0})]  
    return available_buiz

# %% [markdown]
# ### to do
#
# - add a function where i can pass literally a text and it takes elements and puts them into query format
# - geofencing? anyway, obvs also want to retrieve osm data for locations
# - other fancy stuff like: i want parks near bus stops, or reparatur places near parking or sth

# %% [markdown]
# ### query data

# %%
def get_data(coll_osm,coll_yp,query):
    #get osm data
    query_str_osm = create_more_complex_search_string(query,"osm") #create correct query string for yp db
    osm_buiz = retrieve_data(coll_osm, query_str_osm) #just pick up data

    #get yp data
    query_str_yp = create_more_complex_search_string(query,"yp") #create correct query string for yp db
    yp_buiz = retrieve_data(coll_yp, query_str_yp) #just pick up data
    yp_buiz = unique_business(yp_buiz) #make sure everything only once since still many duplicates
    yp_buiz = change_to_LATLON(yp_buiz)

    #concatenate results (since if nothing is found empty list is passed, so no harm done)
    result_set = osm_buiz + yp_buiz

    return result_set

# %%
q = {"what_specific":"Reparatur", "special_tag":"Reparatur"}
r = get_data(coll_osm,coll_yp,q)

# %%
len(r)
# Out:
# 130

# %% [markdown]
# ## Examples with plot

# %%
#reminder:
query_format = {"where":_, # Lübeck                 (search address loc yp)
                "what_general":_,# pub, restaurant etc   (search amenity osm)
                "what_specific":_,# kebab italian        (search name)
                "special_tag":_} # pizza cleaning        (search keywords osm)
#but order doesnt matter

# %%
coll_osm = set_up_mongo('mongodb://localhost:27017','webscraping_dataLabKiel','osm_pois') #establish connection
coll_yp = set_up_mongo('mongodb://localhost:27017','webscraping_dataLabKiel','yellow_pages') #establish connection

# %%
#q = {"what_specific":"Reparatur", "special_tag":"Reparatur"} 130 results
q = {"what_specific":"Reparatur", "special_tag":"Reparatur","what_general":"repair"} #now also search amenity tag, much more
r = get_data(coll_osm,coll_yp,q)
plot_spots(r,8)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1bad03e6da3ea113952a39da29236e51 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1bad03e6da3ea113952a39da29236e51&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1bad03e6da3ea113952a39da29236e51 = L.map(
#                 &quot;map_1bad03e6da3ea113952a39da29236e51&quot;,
#                 {
#                     center: [52.926682545454554, 9.863176576704547],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_801ded1487a348349f2b76a8e7046d6e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_801ded1487a348349f2b76a8e7046d6e.addTo(map_1bad03e6da3ea113952a39da29236e51);
#
#
#             var marker_4f257d559b763493866a99218de97373 = L.marker(
#                 [54.1308163, 8.8583873],
#                 {}
#             ).addTo(map_1bad03e6da3ea113952a39da29236e51);
#
#
#         var popup_86b6011a51edd0d18ff1095d64d0aa35 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e83aea9104f1988ff9cbf88197a7fb53 = $(`&lt;div id=&quot;html_e83aea9104f1988ff9cbf88197a7fb53&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Fahrradverleih &amp; Reparatur Jochen Dethlefs&lt;/b&gt;&lt;br&gt;amenity: bicycle_rental&lt;br&gt;telephone: nan&lt;br&gt;sameAs: nan&lt;/div&gt;`)[0];
#                 popup_86b6011a51edd0d18ff1095d64d0aa35.setContent(html_e83aea9104f1988ff9cbf88197a7fb53);
#
#
#
#         marker_4f257d559b763493866a99218de97373.bindPopup(popup_86b6011a51edd0d18ff1095d64d0aa35)
#         ;
#
#
#
#
#             marker_4f257d559b763493866a99218de97373.bindTooltip(
#                 `&lt;div&gt;
#                      Fahrradverleih &amp; Reparatur Jochen Dethlefs
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8a52bab2b9d7a97edf95104d7239e6fb = L.marker(
#                 [54.0630879, 9.3086326],
#                 {}
#             ).addTo(map_1bad03e6da3ea113952a39da29236e51);
#
#
#         var popup_8980daa87d7dddb6e62c45a5f5df2aab = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_028354d3d7701c0e411672366d3320b3 = $(`&lt;div id=&quot;html_028354d3d7701c0e411672366d3320b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;None&lt;/b&gt;&lt;br&gt;amenity: bicycle_repair_station&lt;br&gt;telephone: nan&lt;br&gt;sameAs: nan&lt;/div&gt;`)[0];
#                 popup_8980daa87d7dddb6e62c45a5f5df2aab.setContent(html_028354d3d7701c0e411672366d3320b3);
#
#
#
#         marker_8a52bab2b9d7a97edf95104d7239e6fb.bindPopup(popup_8980daa87d7dddb6e62c45a5f5df2aab)
#         ;
#
#
#
#
#             var marker_d70bcc4ffaddfc670ad99dd7d616fc57 = L.marker(
#                 [53.8594819, 10.6279563],
#                 {}
#             ).addTo(map_1bad03e6da3ea113952a39da29236e51);
#
#
#         var popup_f3a3c5c4b06d84d3f597d958373dfd2f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a9f65f5c904616e9d7eacc7791f8d608 = $(`&lt;div id=&quot;html_a9f65f5c904616e9d7eacc7791f8d608&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;None&lt;/b&gt;&lt;br&gt;amenity: bicycle_repair_station&lt;br&gt;telephone: nan&lt;br&gt;sameAs: nan&lt;/div&gt;`)[0];
#                 popup_f3a3c5c4b06d84d3f597d958373dfd2f.setContent(html_a9f65f5c904616e9d7eacc7791f8d608);
#
#
#
#         marker_d70bcc4ffaddfc670ad99dd7d616fc57.bindPopup(popup_f3a3c5c4b06d84d3f597d958373dfd2f)
#         ;
#
#
#
#
#             var marker_ab1e6ca6b2392dd8c885e8db55fb76e6 = L.marker(
#                 [54.3378921, 10.124334],
#                 {}
#             ).addTo(map_1bad03e6da3ea113952a39da29236e51);
#
#
#         var popup_655f1b01187a96249d6c2b4ebbbf8e6d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6738fa938ae746919a8bdc9e815a0fe8 = $(`&lt;div id=&quot;html_6738fa938ae746919a8bdc9e815a0fe8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;None&lt;/b&gt;&lt;br&gt;amenity: bicycle_repair_station&lt;br&gt;telephone: nan&lt;br&gt;sameAs: nan&lt;/div&gt;`)[0];
#                 popup_655f1b01187a96249d6c2b4ebbbf8e6d.setContent(html_6738fa938ae746919a8bdc9e815a0fe8);
#
#
#
#         marker_ab1e6ca6b2392dd8c885e8db55fb76e6.bindPopup(popup_655f1b01187a96249d6c2b4ebbbf8e6d)
#         ;
#
#
#
#
#             var marker_654ef8105364eebe100f060a810b5b08 = L.marker(
#                 [54.3385265, 10.1230401],
#                 {}
#             ).addTo(map_1bad03e6da3ea113952a39da29236e51);
#
#
#         var popup_90f4f8da975135ceb8b7a23fe0bd3fc4 = L.popup({&quot;maxWidth&

# %%
#q = {"what_specific":"Kebab"}
q = {"where":"Lübeck","what_specific":"Kebab"} #cancel out all other kebab places because only 1 in yp data right now and no searching in osm due to 'where'
r = get_data(coll_osm,coll_yp,q)
plot_spots(r,8)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a1a15fa5cecac504826cb081a3916ce3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a1a15fa5cecac504826cb081a3916ce3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a1a15fa5cecac504826cb081a3916ce3 = L.map(
#                 &quot;map_a1a15fa5cecac504826cb081a3916ce3&quot;,
#                 {
#                     center: [53.844345, 10.700264],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_71b7a24bef571b2cfbfe9452260ed791 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_71b7a24bef571b2cfbfe9452260ed791.addTo(map_a1a15fa5cecac504826cb081a3916ce3);
#
#
#             var marker_2b8bf16e2cadc40ac4963298c829ca62 = L.marker(
#                 [53.844345, 10.700264],
#                 {}
#             ).addTo(map_a1a15fa5cecac504826cb081a3916ce3);
#
#
#         var popup_e763a1df9b787819fea59e2bae49a1e6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_acc270119fc937e03ab5ea81e6b48e8d = $(`&lt;div id=&quot;html_acc270119fc937e03ab5ea81e6b48e8d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Campus Kebab Bistro&lt;/b&gt;&lt;br&gt;telephone: 0451 59 94 94&lt;/div&gt;`)[0];
#                 popup_e763a1df9b787819fea59e2bae49a1e6.setContent(html_acc270119fc937e03ab5ea81e6b48e8d);
#
#
#
#         marker_2b8bf16e2cadc40ac4963298c829ca62.bindPopup(popup_e763a1df9b787819fea59e2bae49a1e6)
#         ;
#
#
#
#
#             marker_2b8bf16e2cadc40ac4963298c829ca62.bindTooltip(
#                 `&lt;div&gt;
#                      Campus Kebab Bistro
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# try a different collection for yp: we now have only kiel yey

# %%
coll_yp_kiel = set_up_mongo('mongodb://localhost:27017','sh_data_collection','yp_kiel') #establish connection

# %%
q = {"what_specific":"Umzüge", "where":"Kiel", "special_tag":"Umzüge"}
r = get_data(coll_osm,coll_yp_kiel,q)
plot_spots(r,8)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_48aec573168c0c98b3107dfa29ef2303 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_48aec573168c0c98b3107dfa29ef2303&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_48aec573168c0c98b3107dfa29ef2303 = L.map(
#                 &quot;map_48aec573168c0c98b3107dfa29ef2303&quot;,
#                 {
#                     center: [54.31645091304348, 10.126479043478259],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eab6aa80207f9eaca5ee78f1f6bb3374 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_eab6aa80207f9eaca5ee78f1f6bb3374.addTo(map_48aec573168c0c98b3107dfa29ef2303);
#
#
#             var marker_9a84afbedb915b8ef4ed24a71a825184 = L.marker(
#                 [54.31473, 10.125783],
#                 {}
#             ).addTo(map_48aec573168c0c98b3107dfa29ef2303);
#
#
#         var popup_843d45f401b6b84142c2d7efd9b70ee0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0e0a060d139fd7c6fafb2731ceafe50b = $(`&lt;div id=&quot;html_0e0a060d139fd7c6fafb2731ceafe50b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Nordwind Umzüge&lt;/b&gt;&lt;br&gt;telephone: 0431 28 91 09 49&lt;br&gt;sameAs: https://nordwind-umzuege.de&lt;/div&gt;`)[0];
#                 popup_843d45f401b6b84142c2d7efd9b70ee0.setContent(html_0e0a060d139fd7c6fafb2731ceafe50b);
#
#
#
#         marker_9a84afbedb915b8ef4ed24a71a825184.bindPopup(popup_843d45f401b6b84142c2d7efd9b70ee0)
#         ;
#
#
#
#
#             marker_9a84afbedb915b8ef4ed24a71a825184.bindTooltip(
#                 `&lt;div&gt;
#                      Nordwind Umzüge
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f783cf6106354179df59d026dc75232f = L.marker(
#                 [54.272087, 10.156388],
#                 {}
#             ).addTo(map_48aec573168c0c98b3107dfa29ef2303);
#
#
#         var popup_59c7abd4546971903a67c2f7a8f83149 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3c0232d2789481f445b23454da4c67a8 = $(`&lt;div id=&quot;html_3c0232d2789481f445b23454da4c67a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Ulferts &amp; Wittrock GmbH &amp; Co.KG&lt;/b&gt;&lt;br&gt;telephone: 0431 6 47 08-0&lt;br&gt;sameAs: http://www.ulferts-wittrock.de&lt;/div&gt;`)[0];
#                 popup_59c7abd4546971903a67c2f7a8f83149.setContent(html_3c0232d2789481f445b23454da4c67a8);
#
#
#
#         marker_f783cf6106354179df59d026dc75232f.bindPopup(popup_59c7abd4546971903a67c2f7a8f83149)
#         ;
#
#
#
#
#             marker_f783cf6106354179df59d026dc75232f.bindTooltip(
#                 `&lt;div&gt;
#                      Ulferts &amp; Wittrock GmbH &amp; Co.KG
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_bdc796dac929516299d7fcc2b7a854db = L.marker(
#                 [54.35117, 10.091479],
#                 {}
#             ).addTo(map_48aec573168c0c98b3107dfa29ef2303);
#
#
#         var popup_58a2bc072aa029b5bec7589cd7931e8d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d3802649b8ddb62d37ea25de31c4fca4 = $(`&lt;div id=&quot;html_d3802649b8ddb62d37ea25de31c4fca4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Autovermietung Tober - Inh. Marietta Schmiedehausen e.Kfr.&lt;/b&gt;&lt;br&gt;telephone: 0431 9 82 82 82&lt;br&gt;sameAs: http://www.autovermietung-tober.de&lt;/div&gt;`)[0];
#                 popup_58a2bc072aa029b5bec7589cd7931e8d.setContent(html_d3802649b8ddb62d37ea25de31c4fca4);
#
#
#
#         marker_bdc796dac929516299d7fcc2b7a854db.bindPopup(popup_58a2bc072aa029b5bec7589cd7931e8d)
#         ;
#
#
#
#
#             marker_bdc796dac929516299d7fcc2b7a854db.bindTooltip(
#                 `&lt;div&gt;
#                      Autovermietung Tober - Inh. Marietta Schmiedehausen e.Kfr.
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_fd93cdb9d0dc7235c75c943c53e07683 = L.marker(
#                 [54.293365, 10.170539],
#                 {}
#             ).addTo(map_48aec573168c0c98b3107dfa29ef2303);
#
#
#         var popup_7131737e1d59d486a7e422d70acacfb7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1d31d99c7f0f3672a73754ffdbaf161d = $(`&lt;div id=&quot;html_1d31d99c7f0f3672a73754ffdbaf161d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;K. Guttau GmbH &amp; Co. KG Gebäudereinigung&lt;/b&gt;&lt;br&gt;telephone: 0431 7 80 58-0&lt;br

# %%
q = {"what_specific":"Pizza", "where":"Kiel"}
r = get_data(coll_osm,coll_yp_kiel,q)
#print((len(r)))
#print(r[0])
#plot_spots(r[0:13],8)
#plot_spots(r,8) -> doesnt work i dont know why???

# %%
#r[13]

# %%
q = {"what_specific":"Italian", "special_tag":"Pizza"}
r = get_data(coll_osm,coll_yp_kiel,q)
plot_spots(r,8)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b534483ccdf281dc9dddd2df865ab9af {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b534483ccdf281dc9dddd2df865ab9af&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b534483ccdf281dc9dddd2df865ab9af = L.map(
#                 &quot;map_b534483ccdf281dc9dddd2df865ab9af&quot;,
#                 {
#                     center: [54.34307634705882, 10.020700888235293],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fed5c31c3d3016c8d444e57312545b11 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fed5c31c3d3016c8d444e57312545b11.addTo(map_b534483ccdf281dc9dddd2df865ab9af);
#
#
#             var marker_a04fc7d9bc55a68ca204b5f3af798042 = L.marker(
#                 [54.2747801, 10.0742085],
#                 {}
#             ).addTo(map_b534483ccdf281dc9dddd2df865ab9af);
#
#
#         var popup_3e287ace8e8bebef12a9892e45768e1b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f8ca852d266570834a7f44b35a348f62 = $(`&lt;div id=&quot;html_f8ca852d266570834a7f44b35a348f62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Restaurante Italiano&lt;/b&gt;&lt;br&gt;amenity: restaurant&lt;br&gt;telephone: nan&lt;br&gt;sameAs: nan&lt;/div&gt;`)[0];
#                 popup_3e287ace8e8bebef12a9892e45768e1b.setContent(html_f8ca852d266570834a7f44b35a348f62);
#
#
#
#         marker_a04fc7d9bc55a68ca204b5f3af798042.bindPopup(popup_3e287ace8e8bebef12a9892e45768e1b)
#         ;
#
#
#
#
#             marker_a04fc7d9bc55a68ca204b5f3af798042.bindTooltip(
#                 `&lt;div&gt;
#                      Restaurante Italiano
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9bb7e5e21da009ce5798ac886c7ae713 = L.marker(
#                 [54.8616293, 8.6775742],
#                 {}
#             ).addTo(map_b534483ccdf281dc9dddd2df865ab9af);
#
#
#         var popup_1b9715c517bc3bb44aa378c7ab2035e7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_47e63465cc7f7057181c0010f0edc0af = $(`&lt;div id=&quot;html_47e63465cc7f7057181c0010f0edc0af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Olafino - cucina italiana&lt;/b&gt;&lt;br&gt;amenity: restaurant&lt;br&gt;telephone: nan&lt;br&gt;sameAs: nan&lt;/div&gt;`)[0];
#                 popup_1b9715c517bc3bb44aa378c7ab2035e7.setContent(html_47e63465cc7f7057181c0010f0edc0af);
#
#
#
#         marker_9bb7e5e21da009ce5798ac886c7ae713.bindPopup(popup_1b9715c517bc3bb44aa378c7ab2035e7)
#         ;
#
#
#
#
#             marker_9bb7e5e21da009ce5798ac886c7ae713.bindTooltip(
#                 `&lt;div&gt;
#                      Olafino - cucina italiana
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e6a6518d0065466ea79894314c0acfec = L.marker(
#                 [54.4703314, 9.8335113],
#                 {}
#             ).addTo(map_b534483ccdf281dc9dddd2df865ab9af);
#
#
#         var popup_57eb84045f4349a033863f8bd58c533a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5de60ea59501d43b2473b22ae85ddee4 = $(`&lt;div id=&quot;html_5de60ea59501d43b2473b22ae85ddee4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Bistro Italiano Andronaco&lt;/b&gt;&lt;br&gt;amenity: cafe&lt;br&gt;telephone: nan&lt;br&gt;sameAs: nan&lt;/div&gt;`)[0];
#                 popup_57eb84045f4349a033863f8bd58c533a.setContent(html_5de60ea59501d43b2473b22ae85ddee4);
#
#
#
#         marker_e6a6518d0065466ea79894314c0acfec.bindPopup(popup_57eb84045f4349a033863f8bd58c533a)
#         ;
#
#
#
#
#             marker_e6a6518d0065466ea79894314c0acfec.bindTooltip(
#                 `&lt;div&gt;
#                      Bistro Italiano Andronaco
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_fcbc97ed94dfc5f2c87fae44c8f3929c = L.marker(
#                 [54.0996151, 9.9952121],
#                 {}
#             ).addTo(map_b534483ccdf281dc9dddd2df865ab9af);
#
#
#         var popup_6bde2ff2ab71c2e0c87c5f03b59d8ee8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_26c8b1173c20eb0e3053bdf8893f23c8 = $(`&lt;div id=&quot;html_26c8b1173c20eb0e3053bdf8893f23c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Café Italiano&lt;/b&gt;&lt;br&gt;amenity: ice_cream&lt;br&gt;telephone: nan&lt;br&gt;sameAs: nan&lt;/div&gt;`)[0];
#                 popup_6bde2ff2ab71c2e0c87c5f03b59d8ee8.setContent(html_26c8b1173c20eb0e3053bdf
