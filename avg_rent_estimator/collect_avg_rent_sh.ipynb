# %%
from selenium import webdriver
from selenium.webdriver.common.by import By               
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.select import Select

from bs4 import BeautifulSoup

import numpy as np
import pandas as pd
import time
import re

import geopy
from geopy.geocoders import Nominatim

from pymongo import MongoClient
import textwrap

# %%
def set_up_mongo(client_str,database_str,collection_str):
    client = MongoClient(client_str) #connect to mongodb client
    db = client[database_str] #connect to database

    existing_collections = db.list_collection_names() #check that dbs collections
    if collection_str not in existing_collections:
        db.create_collection(collection_str) #create collection if needed
    
    my_collection = db[collection_str] #connect to collection

    return my_collection

# %% [markdown]
# ---
#
# ### scrape all postcodes in sh

# %%
# first scrape all plzs
url = "https://home.meinestadt.de/schleswig-holstein/postleitzahlen"
driver = webdriver.Firefox()
driver.get(url)


time.sleep(10) # -> TEN SECONDS TO CLICK IT
#manage cookie button : manually click it instead it, because its blocked or behind i frame or sth and we just need one website
"""try:
    accept_button = driver.find_element(By.XPATH, "/html/body/div/div[2]/div[4]/div[2]/button")
    accept_button.click()
except:
    print("cant find it")
    accept_button = None"""

soup = BeautifulSoup(driver.page_source, 'html.parser')

driver.close()

# %%
#soup

# %%
r = soup.find_all(class_="m-table__row")

# %%
elements = [res.find_all(class_="m-table__data") for res in r]

# %%
all = []
for element in elements:
    if element is not []:
        results = {}
        for e in element:
            data_label = e.get("data-label")
            if data_label: 
                text = e.text.split()
                if len(text) > 1:
                    text = ' '.join(text) #join list together again but orderly
                elif len(text) > 0:
                    [text] = text
                results.update({f"{data_label}":text})
        all.append(results)

# %%
all[5:10]

# %%
def split_every_five_characters(s):
    return textwrap.wrap(s, 5)

# %%
for a in all:
    if "PLZ" in a.keys():
        plz = a["PLZ"]
        if len(plz) > 5:
            new_plz = split_every_five_characters(plz)
            a["PLZ"] = new_plz
        else:
            a["PLZ"] = [plz] #put also into list for easier processing

# %%
all[5:10]

# %%
len(all)

# %% [markdown]
# ### create one object per plz and add to mongodb & add geopy coordinates

# %%
def geocode_coords(plz,geoloc):
    try:
        geocoded_plz = geoloc.geocode(plz,exactly_one=True)
        if geocoded_plz is not None:
            gca_lat = geocoded_plz.latitude if geocoded_plz.latitude is not None else None
            gca_lon = geocoded_plz.longitude if geocoded_plz.longitude is not None else None
        else:
            gca_lat = None
            gca_lon = None
    except:
        gca_lat = None
        gca_lon = None
    coord_dict = {"lat":gca_lat,"lon":gca_lon}
    return coord_dict

# %%
def create_dict_obj(datapoint):
    my_dict = {"Stadt":datapoint["Stadt"],
               "Stadtteil":datapoint["Stadtteil"],
               "Landkreis":datapoint["Landkreis"],
               "Bundesland":datapoint["Bundesland"]}
    return my_dict

# %%
collection = set_up_mongo('mongodb://localhost:27017','webscraping_dataLabKiel','avg_rent')

# %%
geolocator = Nominatim(user_agent="sad_scraper")
new_results = []

for a in all:
    if "PLZ" in a.keys():
        plz = a["PLZ"]
        if len(plz) > 1:
            for one_plz in plz:
                my_object = create_dict_obj(a)
                #geocode and respect limit on calls
                time.sleep(1)
                coords = geocode_coords(one_plz,geolocator)
                my_object.update({"PLZ":one_plz,"coords":coords})
                #new_results.append(my_object)
                collection.insert_one(my_object)
        else:
            [plz] = plz
            #print(plz)
            #geocode and respect limit on calls
            time.sleep(1)
            coords = geocode_coords(plz,geolocator)
            a.update({"coords":coords,"PLZ":plz})
            #new_results.append(a)
            collection.insert_one(a)

# %%
len(new_results) # so yes new objects were added

# %% [markdown]
# ---

# %% [markdown]
# ## add rent price to objects

# %% [markdown]
# ---

# %%
collection = set_up_mongo('mongodb://localhost:27017','webscraping_dataLabKiel','avg_rent')

# %%
def extract_numbers(n):
    n = n.replace(",",".")
    return float(n)

# %%
def check_if_collected(coll,plz):
    obj = coll.find_one({"PLZ":plz})
    if obj["collected"]=="False":
        return False
    else: 
        return True

# %%
def price_finder(text):
    pattern = re.compile(r"(\d+[,.]\d+)")
    res = pattern.findall(text)
    res = [extract_numbers(r) for r in res]
    price = np.round((sum(res)/len(res)),2) #avergae
    return price

# %%
#collection.update_many({},{"$set":{"collected":"False"}})

# %%
lost_places = []

for e in collection.find():

    identifier = e["_id"]
    p = e["PLZ"]
    city = e["Stadt"].lower()
    city = (city.replace("ü", "ue")
            .replace("ä", "ae")
            .replace("ö", "oe")
            .replace("ß", "ss"))

    if check_if_collected(collection,p) == False:
        url = "https://www.miet-check.de/mietspiegel-uebersicht-alle.php"
        driver = webdriver.Firefox()  
        driver.get(url)

        #deal with cookie button
        try:
            driver.implicitly_wait(10)
            cookie_button = driver.find_element(By.XPATH,'/html/body/dialog/div[2]/div/div[2]/div[2]/div[2]/div[1]/button')
            cookie_button.click()
        except:
            pass

        try:
            annoying_button = driver.find_element(By.XPATH, "/html/body/div[1]/div/div[2]/div/div[3]")
            annoying_button.click()
        except:
            pass

        try:
            annoying_button_2 = driver.find_element(By.XPATH, "/html/body/div[1]/div/div[2]/div/div[3]/button")
            annoying_button_2.click()
        except:
            pass

        price = -1
        try:
            city_button = driver.find_element(By.XPATH, f"//a[@class='btn btn-white btn-sm' and contains(@href,'{city}')]")
            city_button.click()

            html = driver.page_source
            soup = BeautifulSoup(html, 'html.parser')
            driver.quit()

            try:
                text = soup.find(class_="col-sm-12 text-center").text
                price = price_finder(text)
            except:
                pass

            if price == -1:
                try:
                    text = soup.find(id="h2tab1").text
                    price = price_finder(text)
                except:
                    pass
        except:
            pass
            
        if price != -1:
            collection.update_one({"_id":identifier},{"$set":{"average_rent":price,"collected":"True"}})
        else:
            lost_places.append({city:p})
            driver.quit()
                
    else:
        print(f"already got this: {p}")
# Out:
# already got this: 24943
# already got this: 24975
# already got this: 24866
# already got this: 23746
# already got this: 23743
# already got this: 23746
# already got this: 25541
# already got this: 23743
# already got this: 23738
# already got this: 23774
# already got this: 23775
# already got this: 25725
# already got this: 25725
# already got this: 25557
# already got this: 24402
# already got this: 24395
# already got this: 24402
# already got this: 24409
# already got this: 24407
# already got this: 24401
# already got this: 24405
# already got this: 24891
# already got this: 25721
# already got this: 23821
# already got this: 23719
# already got this: 23623
# already got this: 25591
# already got this: 25786
# already got this: 25729
# already got this: 25599
# already got this: 25590
# already got this: 25587
# already got this: 25585
# already got this: 24797
# already got this: 25585
# already got this: 25576
# already got this: 25554
# already got this: 25575
# already got this: 24819
# already got this: 25573
# already got this: 25554
# already got this: 25573
# already got this: 25379
# already got this: 25358
# already got this: 25379
# already got this: 25377
# already got this: 25377
# already got this: 25371
# already got this: 25368
# already got this: 25370
# already got this: 24997
# already got this: 24999
# already got this: 24989
# already got this: 24837
# already got this: 24837
# already got this: 24850
# already got this: 24817
# already got this: 24799
# already got this: 24806
# already got this: 24966
# already got this: 24955
# already got this: 24893
# already got this: 24861
# already got this: 24861
# already got this: 24799
# already got this: 24861
# already got this: 24861
# already got this: 25878
# already got this: 25879
# already got this: 23717
# already got this: 23717
# already got this: 23714
# already got this: 24899
# already got this: 23715
# already got this: 24306
# already got this: 24897
# already got this: 24888
# already got this: 23617
# already got this: 22969
# already got this: 24896
# already got this: 24887
# already got this: 24896
# already got this: 25885
# already got this: 23570
# already got this: 23569
# already got this: 23629
# already got this: 23684
# already got this: 23683
# already got this: 25718
# already got this: 25845
# already got this: 25849
# already got this: 25845
# already got this: 24976
# already got this: 24941
# already got this: 24983
# already got this: 25776
# already got this: 25776
# already got this: 24399
# already got this: 24943
# already got this: 24941
# already got this: 24943
# already got this: 24975
# already got this: 23611
# already got this: 23669
# already got this: 25821
# already got this: 25813
# already got this: 23919
# already got this: 23883
# already got this: 23883
# already got this: 23883
# already got this: 23898
# already got this: 24878
# already got this: 25335
# already got this: 25557
# already got this: 24797
# already got this: 25557
# already got this: 25557
# already got this: 25557
# already got this: 25337
# already got this: 25336
# already got this: 25358
# already got this: 25563
# already got this: 25376
# already got this: 25361
# already got this: 25572
# already got this: 25560
# already got this: 25572
# already got this: 25554
# already got this: 25594
# already got this: 25560
# already got this: 25712
# already got this: 25767
# already got this: 25785
# already got this: 25767
# already got this: 25779
# already got this: 25764
# already got this: 25878
# already got this: 25878
# already got this: 25879
# already got this: 25779
# already got this: 25885
# already got this: 25842
# already got this: 24395
# already got this: 24407
# already got this: 24407
# already got this: 24392
# already got this: 24392
# already got this: 24405
# already got this: 24392
# already got this: 24888
# already got this: 24392
# already got this: 24405
# already got this: 24891
# already got this: 24894
# already got this: 24888
# already got this: 24890
# already got this: 24860
# already got this: 24860
# already got this: 24891
# already got this: 24891
# already got this: 24888
# already got this: 24850
# already got this: 24852
# already got this: 24799
# already got this: 24992
# already got this: 21493
# already got this: 21493
# already got this: 21493
# already got this: 21516
# already got this: 21516
# already got this: 21514
# already got this: 21521
# already got this: 21039
# already got this: 24884
# already got this: 25899
# already got this: 25899
# already got this: 25920
# already got this: 25924
# already got this: 24536
# already got this: 24782
# already got this: 24782
# already got this: 24811
# already got this: 24797
# already got this: 24797
# already got this: 24797
# already got this: 24640
# already got this: 24640
# already got this: 24576
# already got this: 24649
# already got this: 23619
# already got this: 23619
# already got this: 24576
# already got this: 23845
# already got this: 23795
# already got this: 23623
# already got this: 23714
# already got this: 23738
# already got this: 24340
# already got this: 24340
# already got this: 24340
# already got this: 24360
# already got this: 24354
# already got this: 24354
# already got this: 24398
# already got this: 24361
# already got this: 24361
# already got this: 24361
# already got this: 24361
# already got this: 24811
# already got this: 24811
# already got this: 24794
# already got this: 24214
# already got this: 24214
# already got this: 24161
# already got this: 24787
# already got this: 24794
# already got this: 24161
# already got this: 24806
# already got this: 24794
# already got this: 24819
# already got this: 24819
# already got this: 24816
# already got this: 24816
# already got this: 24808
# already got this: 24582
# already got this: 24632
# already got this: 24598
# already got this: 24568
# already got this: 24576
# already got this: 24232
# already got this: 24211
# already got this: 24211
# already got this: 24256
# already got this: 24306
# already got this: 24306
# already got this: 24329
# already got this: 24327
# already got this: 24327
# already got this: 24321
# already got this: 24321
# already got this: 24321
# already got this: 24257
# already got this: 24257
# already got this: 24217
# already got this: 25492
# already got this: 24887

# %%
lost_places
# Out:
# [{'dahme/holstein': '23747'},
#  {'schoenwalde am bungsberg': '23744'},
#  {'grube/holstein': '23749'},
#  {'heringsdorf kr. ostholstein': '23777'},
#  {'neukirchen b. oldenburg': '23777'},
#  {'neukirchen b. oldenburg': '23779'},
#  {'gremersdorf/holstein': '23779'},
#  {'gremersdorf/holstein': '23758'},
#  {'fehmarn (stadt)': '23769'},
#  {'kappeln/schlei': '24404'},
#  {'kappeln/schlei': '24376'},
#  {'huetten b. ascheffel': '24367'},
#  {'huetten b. ascheffel': '24357'},
#  {'huetten b. ascheffel': '24358'},
#  {'osterby b. eckernfoerde': '24367'},
#  {'seedorf b. bad segeberg': '23823'},
#  {'seedorf b. bad segeberg': '24326'},
#  {'klein offenseth-sparrieshoop': '25365'},
#  {'klein bennebek': '24863'},
#  {'klein bennebek': '24848'},
#  {'helgoland': '27498'},
#  {'hooge': '25859'},
#  {'langeness': '25869'},
#  {'langeness': '25863'},
#  {'lehe/dithmarschen': '25774'},
#  {'schwentinental': '24222'},
#  {'schwentinental': '24147'},
#  {'schwentinental': '24223'},
#  {'horstedt b. husum': '25860'},
#  {'gross schenkenberg': '23860'},
#  {'moelln/kr. hzgt. lauenburg': '23879'},
#  {'gross sarau': '23627'},
#  {'ziethen b. ratzeburg': '23909'},
#  {'ziethen b. ratzeburg': '23911'},
#  {'salem b. ratzeburg': '23909'},
#  {'salem b. ratzeburg': '23911'},
#  {'baek b. ratzeburg': '23909'},
#  {'harmsdorf b. ratzeburg': '23911'},
#  {'gross boden': '23847'},
#  {'schenefeld b. hamburg': '22869'},
#  {'tangstedt/kr. pinneberg': '25499'},
#  {'blomesche wildnis': '25348'},
#  {'rade b. fitzbek': '25579'},
#  {'oldendorf/holstein': '25588'},
#  {'quickborn b. dithmarschen': '25693'},
#  {'buesumer deichhausen': '25761'},
#  {'sankt michaelisdonn': '25693'},
#  {'linden/holstein': '25791'},
#  {'hennstedt/dithmarschen': '25791'},
#  {'neuenkirchen/dithmarschen': '25792'},
#  {'drage/nordfriesland': '25840'},
#  {'wisch/nordfriesland': '25876'},
#  {'tetenbuell': '25882'},
#  {'behrendorf b. husum': '25850'},
#  {'ostenfeld/husum': '25872'},
#  {'mittelangeln': '24986'},
#  {'gross rheide': '24848'},
#  {'gross rheide': '24872'},
#  {'klein rheide': '24848'},
#  {'quickborn/kr. pinneberg': '25451'},
#  {'elmenhorst/kr. stormarn': '23869'},
#  {'tangstedt bezirk hamburg': '22889'},
#  {'brodersby-goltoft': '24864'},
#  {'brodersby-goltoft': '24882'},
#  {'steinburg/kr. stormarn': '22964'},
#  {'wentorf b. hamburg': '21465'},
#  {'guelzow/kr. hzgt. lauenburg': '21483'},
#  {'lauenburg/elbe': '21481'},
#  {'aventoft': '25927'},
#  {'brunstorf': '21524'},
#  {'ottendorf b. kiel': '24107'},
#  {'gross kummerfeld': '24626'},
#  {'glinde/kr. stormarn': '21509'},
#  {'alt duvenstedt': '24791'},
#  {'schuelp b. rendsburg': '24813'},
#  {'schuelp b. rendsburg': '24768'},
#  {'nindorf b. neumuenster': '24594'},
#  {'norddorf auf amrum': '25946'},
#  {'kampen/sylt': '25999'},
#  {'kampen/sylt': '25992'},
#  {'hoernum/sylt': '25997'},
#  {'wenningstedt/sylt': '25996'},
#  {'wesenberg b. holstein': '23858'},
#  {'buchholz/forstgutsbezirk': '23812'},
#  {'krems ii': '23827'},
#  {'neustadt/holstein': '23730'},
#  {'holzdorf b. eckernfoerde': '24364'},
#  {'ahlefeld-bistensee': '24358'},
#  {'neu duvenstedt': '24791'},
#  {'ostenfeld/rendsburg': '24790'},
#  {'rade b. rendsburg': '24790'},
#  {'holm/kr. pinneberg': '25488'},
#  {'osdorf b. kiel': '24251'},
#  {'langwedel/holstein': '24631'},
#  {'gross vollstedt': '24802'},
#  {'nortorf b. neumuenster': '24589'},
#  {'gross buchwald': '24637'},
#  {'oldenburg in holstein': '23758'},
#  {'hoegel': '25858'},
#  {'sankt peter-ording': '25826'},
#  {'list auf sylt': '25992'},
#  {'loewenstedt': '25864'},
#  {'hollingstedt b. schleswig': '24876'},
#  {'havetoft': '24873'}]

# %% [markdown]
# ---
#
# # update naming in mondodb

# %%
def set_up_mongo(client_str,database_str,collection_str):
    client = MongoClient(client_str) #connect to mongodb client
    db = client[database_str] #connect to database

    existing_collections = db.list_collection_names() #check that dbs collections
    if collection_str not in existing_collections:
        db.create_collection(collection_str) #create collection if needed
    
    my_collection = db[collection_str] #connect to collection

    return my_collection


collection = set_up_mongo('mongodb://localhost:27017','webscraping_dataLabKiel','avg_rent') 
collection_new = set_up_mongo('mongodb://localhost:27017','webscraping_dataLabKiel','avg_rent_v2') 


for x in collection.find():
    id = x["_id"]
    coords = x["coords"]
    lat = coords["lat"]
    lon = coords["lon"]
    x.update({"lat":lat,"lon":lon})
    #collection_new.insert_one(x)
    collection.update_one({"_id":id},{"$set":{"lat":lat,"lon":lon}})
